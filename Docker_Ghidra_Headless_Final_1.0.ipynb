# %%
# %%time
import pandas as pd
import seaborn as sns
import os
import hashlib
import math
import csv
import itertools
import pandas_bokeh
from collections import Counter
import matplotlib.pyplot as plt

pandas_bokeh.output_notebook()
import jupyter_black

jupyter_black.load()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>
# CPU times: user 2.76 s, sys: 431 ms, total: 3.19 s
# Wall time: 1.99 s

# %% [markdown]
# <h1>Ghidra Headless Script</h1>

# %%
# %%time
# %%writefile gheadless.py
import csv
from ghidra.program.util import DefinedDataIterator, CyclomaticComplexity

dangerous_functions = ["system", "execve", "execle", "execvp", "execlp", "doSystemCmd"]

fm = currentProgram.getFunctionManager()

# Collecting information
files = currentProgram.getName()
arches = currentProgram.getLanguage().toString()
hashes = currentProgram.getExecutableSHA256()
strings = [str(s) for s in DefinedDataIterator.definedStrings(currentProgram)]
all_funcs = list(fm.getFunctions(True))
total_cc = 0
system_xrefs_details = []

# Find dangerous functions and their xrefs
for func in all_funcs:
    if func.getName() in dangerous_functions:
        entry_point = func.getEntryPoint()
        references = getReferencesTo(entry_point)
        for xref in references:
            # Fetching the referencing function details
            ref_func = fm.getFunctionContaining(xref.getFromAddress())
            if ref_func:
                # Collecting address and function name
                detail = "{} ({})".format(xref.getFromAddress(), ref_func.getName())
                system_xrefs_details.append(detail)

num_calls_in_system_xrefs = len(system_xrefs_details)

# Calculating average cyclomatic complexity
for func in all_funcs:
    total_cc += CyclomaticComplexity().calculateCyclomaticComplexity(func, monitor)

# Calculating average cyclomatic complexity
num_funcs = len(all_funcs)
average_cc = total_cc / num_funcs if num_funcs > 0 else 0

# Saving results to CSV
csv_file_path = "./ghidratest.csv"
with open(csv_file_path, mode="a") as csv_file:
    fieldnames = [
        "File",
        "Architecture",
        "SHA256",
        "Strings",
        "Functions",
        "System_Xrefs",
        "Total_System_Xrefs",
        "Average_Cyclomatic_Complexity",
    ]
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    # Writing data
    writer.writerow(
        {
            "File": files,
            "Architecture": arches,
            "SHA256": hashes,
            "Strings": ", ".join(strings),
            "Functions": ", ".join([str(func) for func in all_funcs]),
            "System_Xrefs": "; ".join(system_xrefs_details),
            "Total_System_Xrefs": num_calls_in_system_xrefs,
            "Average_Cyclomatic_Complexity": round(average_cc, 2),
        }
    )
# Out:
# Writing gheadless.py
# CPU times: user 1.99 ms, sys: 146 μs, total: 2.13 ms
# Wall time: 2.11 ms

# %%
# %%time
# !chmod +x gheadless.py
# Out:
# CPU times: user 35.9 ms, sys: 29.5 ms, total: 65.4 ms
# Wall time: 150 ms

# %%
# %%time
ghidra_headless = "/opt/src/ghidra_11.1.2_PUBLIC/support/analyzeHeadless"
# Out:
# CPU times: user 3 μs, sys: 1 μs, total: 4 μs
# Wall time: 5.96 μs

# %%
# !wget https://github.com/therealsaumil/emux/raw/master/files/emux/TRI227WF/rootfs.tar.bz2
# !wget https://github.com/therealsaumil/emux/raw/master/files/emux/AC15/squashfs-root.tar.bz2
# Out:
# --2024-08-09 15:39:18--  https://github.com/therealsaumil/emux/raw/master/files/emux/TRI227WF/rootfs.tar.bz2
# Resolving github.com (github.com)... 20.26.156.215
# Connecting to github.com (github.com)|20.26.156.215|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/therealsaumil/emux/master/files/emux/TRI227WF/rootfs.tar.bz2 [following]
# --2024-08-09 15:39:18--  https://raw.githubusercontent.com/therealsaumil/emux/master/files/emux/TRI227WF/rootfs.tar.bz2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6018759 (5.7M) [application/octet-stream]
# Saving to: ‘rootfs.tar.bz2’
#
# rootfs.tar.bz2      100%[===================>]   5.74M  18.5MB/s    in 0.3s
#
# 2024-08-09 15:39:19 (18.5 MB/s) - ‘rootfs.tar.bz2’ saved [6018759/6018759]
#
# --2024-08-09 15:39:19--  https://github.com/therealsaumil/emux/raw/master/files/emux/AC15/squashfs-root.tar.bz2
# Resolving github.com (github.com)... 20.26.156.215
# Connecting to github.com (github.com)|20.26.156.215|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/therealsaumil/emux/master/files/emux/AC15/squashfs-root.tar.bz2 [following]
# --2024-08-09 15:39:19--  https://raw.githubusercontent.com/therealsaumil/emux/master/files/emux/AC15/squashfs-root.tar.bz2
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11287661 (11M) [application/octet-stream]
# Saving to: ‘squashfs-root.tar.bz2’
#
# squashfs-root.tar.b 100%[===================>]  10.76M  12.3MB/s    in 0.9s
#
# 2024-08-09 15:39:20 (12.3 MB/s) - ‘squashfs-root.tar.bz2’ saved [11287661/11287661]

# %%
# !bzip2 -d ./rootfs.tar.bz2
# !bzip2 -d ./squashfs-root.tar.bz2
# !tar -xvf ./rootfs.tar
# !tar -xvf ./squashfs-root.tar
# Out:
# rootfs/
# rootfs/lib/
# rootfs/lib/libnsl.so.0
# rootfs/lib/libthread_db-0.9.30.2.so
# rootfs/lib/libupnp.so.2.0.3
# rootfs/lib/libutil.so.0
# rootfs/lib/ld-linux.so.3
# rootfs/lib/libupnp.so
# rootfs/lib/libixml.so
# rootfs/lib/libpthread.so.0
# rootfs/lib/librt-0.9.30.2.so
# rootfs/lib/libthreadutil.so.2
# rootfs/lib/ld-uClibc.so.0
# rootfs/lib/libgcc_s.so
# rootfs/lib/libm.so.0
# rootfs/lib/libgcc_s.so.1
# rootfs/lib/libcrypt.so.0
# rootfs/lib/libpthread-0.9.30.2.so
# rootfs/lib/libresolv.so.0
# rootfs/lib/libcrypt-0.9.30.2.so
# rootfs/lib/libdl-0.9.30.2.so
# rootfs/lib/libiw.so.29
# rootfs/lib/libixml.so.2
# rootfs/lib/libdl.so.0
# rootfs/lib/libupnp.so.2
# rootfs/lib/libutil-0.9.30.2.so
# rootfs/lib/ld-uClibc-0.9.30.2.so
# rootfs/lib/librt.so.0
# rootfs/lib/libc.so.0
# rootfs/lib/libresolv-0.9.30.2.so
# rootfs/lib/libthreadutil.so
# rootfs/lib/libthread_db.so.1
# rootfs/lib/libnsl-0.9.30.2.so
# rootfs/lib/libm-0.9.30.2.so
# rootfs/lib/libixml.so.2.0.3
# rootfs/lib/libthreadutil.so.2.1.0
# rootfs/lib/libuClibc-0.9.30.2.so
# rootfs/lib/modules/
# rootfs/lib/modules/fisp0.ko
# rootfs/lib/modules/led.ko
# rootfs/lib/modules/fisp_mt9m034.cfg
# rootfs/lib/modules/fisp_ar0331.ko
# rootfs/lib/modules/fisp_ov9710.cfg
# rootfs/lib/modules/option.ko
# rootfs/lib/modules/fisp_gm_awb.ko
# rootfs/lib/modules/fisp_common.ko
# rootfs/lib/modules/fisp_ov2715.ko
# rootfs/lib/modules/abs628.ko
# rootfs/lib/modules/rtnet3070wps.ko
# rootfs/lib/modules/fisp_gm_ae.ko
# rootfs/lib/modules/fisp_ov2715.cfg
# rootfs/lib/modules/rtutil3070wps.ko
# rootfs/lib/modules/rt3070wps.ko
# rootfs/lib/modules/fisp_ov9710.ko
# rootfs/lib/modules/rt3070sta.ko
# rootfs/lib/modules/fisp_mt9m034.ko
# rootfs/lib/modules/fisp_gm_af.ko
# rootfs/lib/modules/ftcap_isp.ko
# rootfs/lib/modules/fisp_ar0331.cfg
# rootfs/tmp
# rootfs/bin/
# rootfs/bin/egrep
# rootfs/bin/strings
# rootfs/bin/dd
# rootfs/bin/ftpput
# rootfs/bin/echo
# rootfs/bin/readlink
# rootfs/bin/md5sum
# rootfs/bin/dirname
# rootfs/bin/su
# rootfs/bin/more
# rootfs/bin/find
# rootfs/bin/head
# rootfs/bin/cp
# rootfs/bin/delgroup
# rootfs/bin/chvt
# rootfs/bin/id
# rootfs/bin/mkdir
# rootfs/bin/vlock
# rootfs/bin/traceroute
# rootfs/bin/chgrp
# rootfs/bin/logger
# rootfs/bin/cat
# rootfs/bin/wc
# rootfs/bin/touch
# rootfs/bin/kill
# rootfs/bin/usleep
# rootfs/bin/du
# rootfs/bin/openvt
# rootfs/bin/ping
# rootfs/bin/pidof
# rootfs/bin/which
# rootfs/bin/reset
# rootfs/bin/mkdosfs
# rootfs/bin/cut
# rootfs/bin/install
# rootfs/bin/top
# rootfs/bin/bunzip2
# rootfs/bin/dmesg
# rootfs/bin/deallocvt
# rootfs/bin/mesg
# rootfs/bin/gunzip
# rootfs/bin/uniq
# rootfs/bin/sort
# rootfs/bin/vi
# rootfs/bin/grep
# rootfs/bin/zcat
# rootfs/bin/sh
# rootfs/bin/bzcat
# rootfs/bin/busybox
# rootfs/bin/cmp
# rootfs/bin/ls
# rootfs/bin/login
# rootfs/bin/rm
# rootfs/bin/whoami
# rootfs/bin/hostname
# rootfs/bin/lsusb
# rootfs/bin/deluser
# rootfs/bin/adduser
# rootfs/bin/fdisk
# rootfs/bin/chown
# rootfs/bin/mktemp
# rootfs/bin/mv
# rootfs/bin/gzip
# rootfs/bin/rmdir
# rootfs/bin/clear
# rootfs/bin/tar
# rootfs/bin/sleep
# rootfs/bin/addgroup
# rootfs/bin/df
# rootfs/bin/tty
# rootfs/bin/wget
# rootfs/bin/sed
# rootfs/bin/tail
# rootfs/bin/ps
# rootfs/bin/telnetd
# rootfs/bin/arping
# rootfs/bin/ash
# rootfs/bin/pwd
# rootfs/bin/test
# rootfs/bin/tftp
# rootfs/bin/yes
# rootfs/bin/ln
# rootfs/bin/ftpget
# rootfs/bin/awk
# rootfs/bin/free
# rootfs/bin/umount
# rootfs/bin/mount
# rootfs/bin/uname
# rootfs/bin/date
# rootfs/bin/dosfsck
# rootfs/bin/telnet
# rootfs/bin/fgrep
# rootfs/bin/basename
# rootfs/bin/env
# rootfs/bin/uptime
# rootfs/bin/mknod
# rootfs/bin/expr
# rootfs/bin/killall
# rootfs/bin/passwd
# rootfs/bin/true
# rootfs/bin/tr
# rootfs/bin/false
# rootfs/bin/[
# rootfs/bin/hexdump
# rootfs/bin/chmod
# rootfs/usr/
# rootfs/usr/bin/
# rootfs/usr/bin/macpass
# rootfs/usr/bin/usb_modeswitch
# rootfs/usr/bin/chkvsize
# rootfs/usr/bin/iwscan
# rootfs/usr/bin/shell
# rootfs/usr/bin/mybox
# rootfs/usr/bin/mtdfirmware
# rootfs/usr/bin/netmgr
# rootfs/usr/bin/iwstat
# rootfs/usr/bin/rc
# rootfs/usr/bin/user
# rootfs/usr/bin/ntpdate
# rootfs/usr/bin/iwconfig
# rootfs/usr/bin/onvifd
# rootfs/usr/bin/dropbox_up.sh
# rootfs/usr/bin/agricamclient
# rootfs/usr/bin/ndcpd2
# rootfs/usr/bin/iwlist
# rootfs/usr/bin/ltrace
# rootfs/usr/bin/ndcpd
# rootfs/usr/bin/inetd_tcp
# rootfs/usr/bin/service
# rootfs/usr/bin/autoreboot
# rootfs/usr/bin/checkinternet
# rootfs/usr/bin/iwpriv
# rootfs/usr/bin/storage
# rootfs/usr/bin/rp-pppoe.so
# rootfs/usr/bin/i2c_access
# rootfs/usr/bin/wpsbutton
# rootfs/usr/bin/sysreboot
# rootfs/usr/bin/iwsetup
# rootfs/usr/bin/eraseall
# rootfs/usr/bin/xmatrix
# rootfs/usr/bin/httpclient
# rootfs/usr/bin/execd
# rootfs/usr/bin/inetd_rdt
# rootfs/usr/bin/nc
# rootfs/usr/bin/dropbox_reg1.sh
# rootfs/usr/bin/isp_test_v3
# rootfs/usr/bin/onvifn
# rootfs/usr/bin/wlanautoselect
# rootfs/usr/bin/curl
# rootfs/usr/bin/mtdcp
# rootfs/usr/bin/taskmgr
# rootfs/usr/bin/pppmgr
# rootfs/usr/bin/osd
# rootfs/usr/bin/rthpd
# rootfs/usr/bin/dropbox_unreg.sh
# rootfs/usr/bin/resetbutton
# rootfs/usr/bin/ndcpd3
# rootfs/usr/bin/ioctld
# rootfs/usr/bin/taskbox
# rootfs/usr/bin/smtpclient
# rootfs/usr/bin/mount.cifs
# rootfs/usr/bin/adhocbutton
# rootfs/usr/bin/pppd
# rootfs/usr/bin/iwtest
# rootfs/usr/bin/led
# rootfs/usr/bin/inadyn
# rootfs/usr/bin/dnscache
# rootfs/usr/bin/osdbitmap
# rootfs/usr/bin/sched
# rootfs/usr/bin/chat
# rootfs/usr/bin/upkill
# rootfs/usr/bin/battery
# rootfs/usr/bin/dropboxclient
# rootfs/usr/bin/webs
# rootfs/usr/bin/avsetting
# rootfs/usr/bin/ftpclient
# rootfs/usr/bin/buzzer
# rootfs/usr/bin/videoset
# rootfs/usr/bin/upnpd
# rootfs/usr/bin/nvrd
# rootfs/usr/bin/sysconf
# rootfs/usr/bin/modemtest
# rootfs/usr/bin/ipcamd
# rootfs/usr/bin/rawdev
# rootfs/usr/bin/strace
# rootfs/usr/bin/watchdog
# rootfs/usr/bin/mtdusrlocal
# rootfs/usr/bin/ddns
# rootfs/usr/bin/nvctl
# rootfs/usr/bin/audioset
# rootfs/usr/bin/downloadfw
# rootfs/usr/bin/batbutton
# rootfs/usr/bin/sdformat
# rootfs/usr/bin/iwwps
# rootfs/usr/bin/dropbox_reg2.sh
# rootfs/usr/local/
# rootfs/dev/
# rootfs/dev/favcenc
# tar: rootfs/dev/favcenc: Cannot mknod: Operation not permitted
# rootfs/dev/tty0
# tar: rootfs/dev/tty0: Cannot mknod: Operation not permitted
# rootfs/dev/fdec
# tar: rootfs/dev/fdec: Cannot mknod: Operation not permitted
# rootfs/dev/ttyUSB4
# tar: rootfs/dev/ttyUSB4: Cannot mknod: Operation not permitted
# rootfs/dev/video0
# tar: rootfs/dev/video0: Cannot mknod: Operation not permitted
# rootfs/dev/ttyS0
# tar: rootfs/dev/ttyS0: Cannot mknod: Operation not permitted
# rootfs/dev/hda
# tar: rootfs/dev/hda: Cannot mknod: Operation not permitted
# rootfs/dev/mmcblk0
# tar: rootfs/dev/mmcblk0: Cannot mknod: Operation not permitted
# rootfs/dev/stdin
# rootfs/dev/stdout
# rootfs/dev/hdc3
# tar: rootfs/dev/hdc3: Cannot mknod: Operation not permitted
# rootfs/dev/mtdblock0
# tar: rootfs/dev/mtdblock0: Cannot mknod: Operation not permitted
# rootfs/dev/button2
# tar: rootfs/dev/button2: Cannot mknod: Operation not permitted
# rootfs/dev/hdc1
# tar: rootfs/dev/hdc1: Cannot mknod: Operation not permitted
# rootfs/dev/mtd4
# tar: rootfs/dev/mtd4: Cannot mknod: Operation not permitted
# rootfs/dev/console
# tar: rootfs/dev/console: Cannot mknod: Operation not permitted
# rootfs/dev/mmca1
# tar: rootfs/dev/mmca1: Cannot mknod: Operation not permitted
# rootfs/dev/dsp
# tar: rootfs/dev/dsp: Cannot mknod: Operation not permitted
# rootfs/dev/acodec
# tar: rootfs/dev/acodec: Cannot mknod: Operation not permitted
# rootfs/dev/null
# tar: rootfs/dev/null: Cannot mknod: Operation not permitted
# rootfs/dev/ttyp0
# tar: rootfs/dev/ttyp0: Cannot mknod: Operation not permitted
# rootfs/dev/ptyp3
# tar: rootfs/dev/ptyp3: Cannot mknod: Operation not permitted
# rootfs/dev/ttyp1
# tar: rootfs/dev/ttyp1: Cannot mknod: Operation not permitted
# rootfs/dev/ttyS2
# tar: rootfs/dev/ttyS2: Cannot mknod: Operation not permitted
# rootfs/dev/mtd3
# tar: rootfs/dev/mtd3: Cannot mknod: Operation not permitted
# rootfs/dev/zero
# tar: rootfs/dev/zero: Cannot mknod: Operation not permitted
# rootfs/dev/ram0
# tar: rootfs/dev/ram0: Cannot mknod: Operation not permitted
# rootfs/dev/mtdblock1
# tar: rootfs/dev/mtdblock1: Cannot mknod: Operation not permitted
# rootfs/dev/mtdparam
# rootfs/dev/mjdec
# tar: rootfs/dev/mjdec: Cannot mknod: Operation not permitted
# rootfs/dev/tty1
# tar: rootfs/dev/tty1: Cannot mknod: Operation not permitted
# rootfs/dev/stderr
# rootfs/dev/i2c-0
# tar: rootfs/dev/i2c-0: Cannot mknod: Operation not permitted
# rootfs/dev/random
# tar: rootfs/dev/random: Cannot mknod: Operation not permitted
# rootfs/dev/mtdblock2
# tar: rootfs/dev/mtdblock2: Cannot mknod: Operation not permitted
# rootfs/dev/hda2
# tar: rootfs/dev/hda2: Cannot mknod: Operation not permitted
# rootfs/dev/mjenc
# tar: rootfs/dev/mjenc: Cannot mknod: Operation not permitted
# rootfs/dev/ptyp0
# tar: rootfs/dev/ptyp0: Cannot mknod: Operation not permitted
# rootfs/dev/sda1
# tar: rootfs/dev/sda1: Cannot mknod: Operation not permitted
# rootfs/dev/button3
# tar: rootfs/dev/button3: Cannot mknod: Operation not permitted
# rootfs/dev/ppp
# tar: rootfs/dev/ppp: Cannot mknod: Operation not permitted
# rootfs/dev/fd0
# tar: rootfs/dev/fd0: Cannot mknod: Operation not permitted
# rootfs/dev/tty3
# tar: rootfs/dev/tty3: Cannot mknod: Operation not permitted
# rootfs/dev/tty
# tar: rootfs/dev/tty: Cannot mknod: Operation not permitted
# rootfs/dev/binder
# tar: rootfs/dev/binder: Cannot mknod: Operation not permitted
# rootfs/dev/hdc
# tar: rootfs/dev/hdc: Cannot mknod: Operation not permitted
# rootfs/dev/hdc4
# tar: rootfs/dev/hdc4: Cannot mknod: Operation not permitted
# rootfs/dev/fb0
# tar: rootfs/dev/fb0: Cannot mknod: Operation not permitted
# rootfs/dev/abs628
# tar: rootfs/dev/abs628: Cannot mknod: Operation not permitted
# rootfs/dev/led
# tar: rootfs/dev/led: Cannot mknod: Operation not permitted
# rootfs/dev/ptyp1
# tar: rootfs/dev/ptyp1: Cannot mknod: Operation not permitted
# rootfs/dev/ttyUSB5
# tar: rootfs/dev/ttyUSB5: Cannot mknod: Operation not permitted
# rootfs/dev/mtd0
# tar: rootfs/dev/mtd0: Cannot mknod: Operation not permitted
# rootfs/dev/ioctl
# tar: rootfs/dev/ioctl: Cannot mknod: Operation not permitted
# rootfs/dev/button0
# tar: rootfs/dev/button0: Cannot mknod: Operation not permitted
# rootfs/dev/mmca
# tar: rootfs/dev/mmca: Cannot mknod: Operation not permitted
# rootfs/dev/fmd
# tar: rootfs/dev/fmd: Cannot mknod: Operation not permitted
# rootfs/dev/sda
# tar: rootfs/dev/sda: Cannot mknod: Operation not permitted
# rootfs/dev/ttyp2
# tar: rootfs/dev/ttyp2: Cannot mknod: Operation not permitted
# rootfs/dev/mtdblock3
# tar: rootfs/dev/mtdblock3: Cannot mknod: Operation not permitted
# rootfs/dev/dsp1
# tar: rootfs/dev/dsp1: Cannot mknod: Operation not permitted
# rootfs/dev/mtdcfg
# rootfs/dev/ftdi
# tar: rootfs/dev/ftdi: Cannot mknod: Operation not permitted
# rootfs/dev/hda3
# tar: rootfs/dev/hda3: Cannot mknod: Operation not permitted
# rootfs/dev/tty2
# tar: rootfs/dev/tty2: Cannot mknod: Operation not permitted
# rootfs/dev/ttyUSB0
# tar: rootfs/dev/ttyUSB0: Cannot mknod: Operation not permitted
# rootfs/dev/vcodec
# tar: rootfs/dev/vcodec: Cannot mknod: Operation not permitted
# rootfs/dev/mmcblk0p1
# tar: rootfs/dev/mmcblk0p1: Cannot mknod: Operation not permitted
# rootfs/dev/battery
# tar: rootfs/dev/battery: Cannot mknod: Operation not permitted
# rootfs/dev/mtd2
# tar: rootfs/dev/mtd2: Cannot mknod: Operation not permitted
# rootfs/dev/sda2
# tar: rootfs/dev/sda2: Cannot mknod: Operation not permitted
# rootfs/dev/ttyUSB3
# tar: rootfs/dev/ttyUSB3: Cannot mknod: Operation not permitted
# rootfs/dev/fd
# rootfs/dev/ttyUSB2
# tar: rootfs/dev/ttyUSB2: Cannot mknod: Operation not permitted
# rootfs/dev/ttyS3
# tar: rootfs/dev/ttyS3: Cannot mknod: Operation not permitted
# rootfs/dev/hda1
# tar: rootfs/dev/hda1: Cannot mknod: Operation not permitted
# rootfs/dev/ttyUSB6
# tar: rootfs/dev/ttyUSB6: Cannot mknod: Operation not permitted
# rootfs/dev/watchdog
# tar: rootfs/dev/watchdog: Cannot mknod: Operation not permitted
# rootfs/dev/mtd1
# tar: rootfs/dev/mtd1: Cannot mknod: Operation not permitted
# rootfs/dev/ttyUSB1
# tar: rootfs/dev/ttyUSB1: Cannot mknod: Operation not permitted
# rootfs/dev/ttyp3
# tar: rootfs/dev/ttyp3: Cannot mknod: Operation not permitted
# rootfs/dev/log
# rootfs/dev/mtdusrlocal
# rootfs/dev/isp0
# tar: rootfs/dev/isp0: Cannot mknod: Operation not permitted
# rootfs/dev/button1
# tar: rootfs/dev/button1: Cannot mknod: Operation not permitted
# rootfs/dev/nvctl
# tar: rootfs/dev/nvctl: Cannot mknod: Operation not permitted
# rootfs/dev/hdc2
# tar: rootfs/dev/hdc2: Cannot mknod: Operation not permitted
# rootfs/dev/ttyS1
# tar: rootfs/dev/ttyS1: Cannot mknod: Operation not permitted
# rootfs/dev/rtc
# tar: rootfs/dev/rtc: Cannot mknod: Operation not permitted
# rootfs/dev/hda4
# tar: rootfs/dev/hda4: Cannot mknod: Operation not permitted
# rootfs/dev/ptyp2
# tar: rootfs/dev/ptyp2: Cannot mknod: Operation not permitted
# rootfs/dev/urandom
# tar: rootfs/dev/urandom: Cannot mknod: Operation not permitted
# rootfs/dev/ram1
# tar: rootfs/dev/ram1: Cannot mknod: Operation not permitted
# rootfs/dev/dtmf
# tar: rootfs/dev/dtmf: Cannot mknod: Operation not permitted
# rootfs/dev/video1
# tar: rootfs/dev/video1: Cannot mknod: Operation not permitted
# rootfs/dev/fenc
# tar: rootfs/dev/fenc: Cannot mknod: Operation not permitted
# rootfs/dev/fscaler
# tar: rootfs/dev/fscaler: Cannot mknod: Operation not permitted
# rootfs/root/
# rootfs/root/.ash_history
# rootfs/sys/
# rootfs/home/
# rootfs/home/web/
# rootfs/home/web/mobile/
# rootfs/home/web/mobile/default.asp
# rootfs/home/web/config.cfg
# rootfs/home/web/debug/
# rootfs/home/web/debug/p2p.asp
# rootfs/home/web/debug/css/
# rootfs/home/web/debug/css/head.css
# rootfs/home/web/debug/default.asp
# rootfs/home/web/debug/rawdev.asp
# rootfs/home/web/debug/macaddr.asp
# rootfs/home/web/debug/syslogd.txt
# rootfs/home/web/debug/error.htm
# rootfs/home/web/debug/ok.htm
# rootfs/home/web/debug/syslogd.htm
# rootfs/home/web/default.asp
# rootfs/home/web/en/
# rootfs/home/web/en/ioctld_nvs.asp
# rootfs/home/web/en/mobile/
# rootfs/home/web/en/mobile/mblive.asp
# rootfs/home/web/en/mobile/mblogin.asp
# rootfs/home/web/en/mobile/mbsetup.asp
# rootfs/home/web/en/pppoe.asp
# rootfs/home/web/en/sdformat.asp
# rootfs/home/web/en/bottom.htm
# rootfs/home/web/en/account/
# rootfs/home/web/en/account/accadd.asp
# rootfs/home/web/en/account/acclist.asp
# rootfs/home/web/en/account/accedit.asp
# rootfs/home/web/en/wlan.asp
# rootfs/home/web/en/p2p.asp
# rootfs/home/web/en/css/
# rootfs/home/web/en/css/head.css
# rootfs/home/web/en/css/ws.css
# rootfs/home/web/en/css/mobile.css
# rootfs/home/web/en/css/help.css
# rootfs/home/web/en/css/top.css
# rootfs/home/web/en/css/menu.css
# rootfs/home/web/en/css/doc.css
# rootfs/home/web/en/bootwait.asp
# rootfs/home/web/en/streamlist2.asp
# rootfs/home/web/en/message.msg
# rootfs/home/web/en/formating.asp
# rootfs/home/web/en/identity.asp
# rootfs/home/web/en/main.asp
# rootfs/home/web/en/tcpip.asp
# rootfs/home/web/en/nvctl_nosensor.asp
# rootfs/home/web/en/streamlist1.asp
# rootfs/home/web/en/motiondect_other.htm
# rootfs/home/web/en/support.htm
# rootfs/home/web/en/autoreboot.asp
# rootfs/home/web/en/ssidlist.asp
# rootfs/home/web/en/reboot.asp
# rootfs/home/web/en/clock.asp
# rootfs/home/web/en/wlantestsuccess.htm
# rootfs/home/web/en/login.asp
# rootfs/home/web/en/buzzer.asp
# rootfs/home/web/en/sysinfo.asp
# rootfs/home/web/en/rightframe.htm
# rootfs/home/web/en/upnpd.asp
# rootfs/home/web/en/image.asp
# rootfs/home/web/en/wizard/
# rootfs/home/web/en/wizard/wizard_ip_ipanddns.asp
# rootfs/home/web/en/wizard/wizard_wlan_noresult.asp
# rootfs/home/web/en/wizard/wizard_end_page.asp
# rootfs/home/web/en/wizard/wizard_wlan_wpa.asp
# rootfs/home/web/en/wizard/wizard_wlan_scanning.asp
# rootfs/home/web/en/wizard/wizard_wlan_scanresult.asp
# rootfs/home/web/en/wizard/wizard_wlan_wep.asp
# rootfs/home/web/en/wizard/rebootwait.asp
# rootfs/home/web/en/wizard/wizard_wlan_setting.asp
# rootfs/home/web/en/wizard/wizard_dateandtime.asp
# rootfs/home/web/en/wizard/wizard_wlan_sel_security.asp
# rootfs/home/web/en/wizard/wizard_welcome_page.asp
# rootfs/home/web/en/wizard/wizard_camera_name.asp
# rootfs/home/web/en/wizard/wizard_camera_quality.asp
# rootfs/home/web/en/wizard/wizard_ip_type.asp
# rootfs/home/web/en/wizard/wizard_timezone.asp
# rootfs/home/web/en/wizard/wizard_wlan_scantype.asp
# rootfs/home/web/en/wlantestfail.htm
# rootfs/home/web/en/ppp.asp
# rootfs/home/web/en/ioctld.asp
# rootfs/home/web/en/setting.asp
# rootfs/home/web/en/modemtest.asp
# rootfs/home/web/en/storagebrowse.asp
# rootfs/home/web/en/top.htm
# rootfs/home/web/en/schedule.asp
# rootfs/home/web/en/face.asp
# rootfs/home/web/en/osd.asp
# rootfs/home/web/en/menu.asp
# rootfs/home/web/en/motiondect.htm
# rootfs/home/web/en/streamlist0.asp
# rootfs/home/web/en/stream.asp
# rootfs/home/web/en/images/
# rootfs/home/web/en/images/signal3.gif
# rootfs/home/web/en/images/wait.gif
# rootfs/home/web/en/images/signal4.gif
# rootfs/home/web/en/images/top_bk.gif
# rootfs/home/web/en/images/searching.gif
# rootfs/home/web/en/images/none.gif
# rootfs/home/web/en/images/win_bak.jpg
# rootfs/home/web/en/images/frame_left_top.png
# rootfs/home/web/en/images/signal5.gif
# rootfs/home/web/en/images/bottom_right.gif
# rootfs/home/web/en/images/bottom_left.gif
# rootfs/home/web/en/images/left_bk.gif
# rootfs/home/web/en/images/login.png
# rootfs/home/web/en/images/signal1.gif
# rootfs/home/web/en/images/top_right.png
# rootfs/home/web/en/images/wizard_bk.png
# rootfs/home/web/en/images/p1.gif
# rootfs/home/web/en/images/bottom_bk.gif
# rootfs/home/web/en/images/top_left.png
# rootfs/home/web/en/images/signal2.gif
# rootfs/home/web/en/images/p2.gif
# rootfs/home/web/en/images/menu_bk.gif
# rootfs/home/web/en/wlantesting.asp
# rootfs/home/web/en/ddns.asp
# rootfs/home/web/en/player/
# rootfs/home/web/en/player/activex_hd.asp
# rootfs/home/web/en/player/flash_hd.asp
# rootfs/home/web/en/player/hls_hd.asp
# rootfs/home/web/en/player/flash_pal.asp
# rootfs/home/web/en/player/qt_pal.asp
# rootfs/home/web/en/player/qt_vga.asp
# rootfs/home/web/en/player/hls_pal.asp
# rootfs/home/web/en/player/mjpeg_hd.asp
# rootfs/home/web/en/player/hls_vga.asp
# rootfs/home/web/en/player/activex_pal.asp
# rootfs/home/web/en/player/flash_vga.asp
# rootfs/home/web/en/player/mjpeg_pal.asp
# rootfs/home/web/en/player/activex_vga.asp
# rootfs/home/web/en/player/qt_hd.asp
# rootfs/home/web/en/player/mjpeg_vga.asp
# rootfs/home/web/en/searchingssid.asp
# rootfs/home/web/en/task/
# rootfs/home/web/en/task/storageftp.asp
# rootfs/home/web/en/task/storageftp_ftp.asp
# rootfs/home/web/en/task/periodrecordftp.asp
# rootfs/home/web/en/task/alarmsnapshotftp_ftp.asp
# rootfs/home/web/en/task/periodsnapshotemail.asp
# rootfs/home/web/en/task/periodhttp.asp
# rootfs/home/web/en/task/alarmhttp.asp
# rootfs/home/web/en/task/periodrecordstorage.asp
# rootfs/home/web/en/task/alarmsnapshotemail.asp
# rootfs/home/web/en/task/alarmrecordstorage.asp
# rootfs/home/web/en/task/tasklist.asp
# rootfs/home/web/en/task/alarmrecordftp.asp
# rootfs/home/web/en/task/dropboxconfigstep2.asp
# rootfs/home/web/en/task/periodrecordftp_ftp.asp
# rootfs/home/web/en/task/dropboxconfigstep1.asp
# rootfs/home/web/en/task/alarmsnapshotstorage.asp
# rootfs/home/web/en/task/periodsnapshotftp.asp
# rootfs/home/web/en/task/pushnotification.asp
# rootfs/home/web/en/task/alarmsnapshothttp.asp
# rootfs/home/web/en/task/alarmrecordftp_ftp.asp
# rootfs/home/web/en/task/periodsnapshotftp_ftp.asp
# rootfs/home/web/en/task/periodsnapshotstorage.asp
# rootfs/home/web/en/task/agricamhttp.asp
# rootfs/home/web/en/task/alarmsnapshotftp.asp
# rootfs/home/web/en/task/periodsnapshothttp.asp
# rootfs/home/web/en/upgrade/
# rootfs/home/web/en/upgrade/fmterr.htm
# rootfs/home/web/en/upgrade/success.htm
# rootfs/home/web/en/upgrade/upgrading.htm
# rootfs/home/web/en/upgrade/upgrade.htm
# rootfs/home/web/en/upgrade/upkill.htm
# rootfs/home/web/en/upgrade/memerr.htm
# rootfs/home/web/en/storagelist.asp
# rootfs/home/web/en/storageplay.asp
# rootfs/home/web/en/adhoc.asp
# rootfs/home/web/en/storage.asp
# rootfs/home/web/en/window.swf
# rootfs/home/web/en/motiondect_other.asp
# rootfs/home/web/en/modemtesting.asp
# rootfs/home/web/en/nvctl.asp
# rootfs/home/web/en/rthpd.asp
# rootfs/home/web/en/relogin.asp
# rootfs/home/web/en/motiondect.asp
# rootfs/home/web/en/camera.asp
# rootfs/home/web/flash/
# rootfs/home/web/flash/jwplayer.js
# rootfs/home/web/flash/jwplayer.flash.swf
# rootfs/home/web/cgi-bin/
# rootfs/home/web/cab/
# rootfs/home/web/cab/ipcamera.cab
# rootfs/home/web/cab/NcPlayrt.cab
# rootfs/home/web/images/
# rootfs/home/web/images/activex_pal_right_top.png
# rootfs/home/web/images/qt_bottom.png
# rootfs/home/web/images/qt_hd_right_top.png
# rootfs/home/web/images/qt_hd_bottom.png
# rootfs/home/web/images/flash_vga_bottom.png
# rootfs/home/web/images/activex_hd_right_top.png
# rootfs/home/web/images/activex_vga_right_top.png
# rootfs/home/web/images/qt_right_top.png
# rootfs/home/web/images/activex_hd_bottom.png
# rootfs/home/web/images/flash_vga_right_top.png
# rootfs/home/web/images/activex_pal_bottom.png
# rootfs/home/web/images/activex_vga_bottom.png
# rootfs/home/web/images/mjpeg_bottom.png
# rootfs/home/web/images/flash_hd_bottom.png
# rootfs/home/web/images/flash_hd_right_top.png
# rootfs/home/web/disk
# rootfs/home/disk/
# rootfs/etc/
# rootfs/etc/group
# rootfs/etc/services
# rootfs/etc/resolv.conf
# rootfs/etc/ndcpd/
# rootfs/etc/ndcpd/ndcpd.conf
# rootfs/etc/TZ
# rootfs/etc/ntp/
# rootfs/etc/ntp/time-update.local
# rootfs/etc/ntp/ntpdate.conf
# rootfs/etc/inittab
# rootfs/etc/xntask/
# rootfs/etc/xntask/init
# rootfs/etc/fstab
# rootfs/etc/ltrace.conf
# rootfs/etc/dhcpc/
# rootfs/etc/dhcpc/ip-down
# rootfs/etc/dhcpc/ip-up
# rootfs/etc/sys.conf
# rootfs/etc/ppp/
# rootfs/etc/ppp/resolv.conf
# rootfs/etc/ppp/ip-down
# rootfs/etc/ppp/connect-errors
# rootfs/etc/ppp/connect
# rootfs/etc/ppp/ip-up
# rootfs/etc/ppp/network
# rootfs/etc/ppp/pap-secrets
# rootfs/etc/ppp/chap-secrets
# rootfs/etc/ppp/options
# rootfs/etc/wpa_supplicant/
# rootfs/etc/wpa_supplicant/wpa_supplicant.conf
# rootfs/etc/init.d/
# rootfs/etc/init.d/rc
# rootfs/etc/init.d/ds921x1622_2
# rootfs/etc/init.d/rc.sysinit
# rootfs/etc/init.d/ds921x1622
# rootfs/etc/default/
# rootfs/etc/default/sys.conf.ORIGINAL
# rootfs/etc/default/umconfig.txt
# rootfs/etc/default/sys.conf
# rootfs/etc/sysconfig/
# rootfs/etc/sysconfig/network
# rootfs/etc/sysconfig/network-scripts/
# rootfs/etc/sysconfig/network-scripts/ifcfg-ppp
# rootfs/etc/sysconfig/network-scripts/ifcfg-pppoe
# rootfs/etc/sysconfig/network-scripts/ifcfg-lo
# rootfs/etc/sysconfig/network-scripts/ifdown
# rootfs/etc/sysconfig/network-scripts/ifup
# rootfs/etc/sysconfig/network-scripts/ifcfg-netif
# rootfs/etc/webs/
# rootfs/etc/webs/umconfig.txt
# rootfs/etc/webs/webs.conf
# rootfs/etc/webs/webs.acc
# rootfs/etc/upnpd/
# rootfs/etc/upnpd/dummy.xml
# rootfs/etc/upnpd/description.xml
# rootfs/etc/upnpd/upnpd.conf
# rootfs/etc/upnpd/ligd.gif
# rootfs/etc/sysconf/
# rootfs/etc/sysconf/sys.mask
# rootfs/etc/Wireless/
# rootfs/etc/Wireless/RT3070STA/
# rootfs/etc/Wireless/RT3070STA/RT3070STA.dat
# rootfs/etc/Wireless/RT73STA/
# rootfs/etc/Wireless/RT73STA/rt73sta.dat
# rootfs/etc/passwd
# rootfs/etc/hosts
# rootfs/sbin/
# rootfs/sbin/httpd
# rootfs/sbin/udhcpc
# rootfs/sbin/lsmod
# rootfs/sbin/hwclock
# rootfs/sbin/swapoff
# rootfs/sbin/pivot_root
# rootfs/sbin/modprobe
# rootfs/sbin/inetd
# rootfs/sbin/getty
# rootfs/sbin/sysctl
# rootfs/sbin/syslogd
# rootfs/sbin/ifconfig
# rootfs/sbin/chroot
# rootfs/sbin/reboot
# rootfs/sbin/insmod
# rootfs/sbin/udhcpd
# rootfs/sbin/sulogin
# rootfs/sbin/init
# rootfs/sbin/swapon
# rootfs/sbin/telnetd
# rootfs/sbin/route
# rootfs/sbin/rmmod
# rootfs/sbin/klogd
# rootfs/sbin/mkswap
# rootfs/sbin/halt
# rootfs/sbin/poweroff
# rootfs/proc/
# rootfs/var/
# rootfs/var/lib/
# rootfs/var/tmp/
# rootfs/var/lock/
# rootfs/var/lock/watchdog_ipcamd
# rootfs/var/log/
# rootfs/var/run/
# tar: Exiting with failure status due to previous errors
# squashfs-root/
# squashfs-root/lib/
# squashfs-root/lib/libnsl.so.0
# squashfs-root/lib/pptp.so
# squashfs-root/lib/libCfm.so
# squashfs-root/lib/libexif.so.12
# squashfs-root/lib/libavutil.so.50
# squashfs-root/lib/libbcm.so
# squashfs-root/lib/libz.so
# squashfs-root/lib/libutil.so.0
# squashfs-root/lib/libsqlite3.so.0
# squashfs-root/lib/libupnp.so
# squashfs-root/lib/libChipApi.so
# squashfs-root/lib/libFLAC.so.8
# squashfs-root/lib/libpthread.so.0
# squashfs-root/lib/libid3tag.so.0
# squashfs-root/lib/rp-pppoe.so
# squashfs-root/lib/libtpi.so
# squashfs-root/lib/Makefile
# squashfs-root/lib/libfoo.so
# squashfs-root/lib/ld-uClibc.so.0
# squashfs-root/lib/libshared.so
# squashfs-root/lib/libm.so.0
# squashfs-root/lib/libgcc_s.so.1
# squashfs-root/lib/libcrypt.so.0
# squashfs-root/lib/libavformat.so.52
# squashfs-root/lib/libresolv.so.0
# squashfs-root/lib/libpal_vendor.so
# squashfs-root/lib/libntfs-3g.so.81
# squashfs-root/lib/libbcmcrypto.so
# squashfs-root/lib/libcrypto.so.1.0.0
# squashfs-root/lib/libvos_util.so
# squashfs-root/lib/libcloud.so
# squashfs-root/lib/libavcodec.so.52
# squashfs-root/lib/libdl.so.0
# squashfs-root/lib/libucapi.so
# squashfs-root/lib/libogg.so.0
# squashfs-root/lib/librt.so.0
# squashfs-root/lib/libc.so.0
# squashfs-root/lib/libflow.so
# squashfs-root/lib/libnvram.so
# squashfs-root/lib/pppol2tp.so
# squashfs-root/lib/libcrypto.so
# squashfs-root/lib/libz.so.1
# squashfs-root/lib/libvorbis.so.0
# squashfs-root/lib/libjpeg.so
# squashfs-root/lib/libcommon.so
# squashfs-root/lib/modules/
# squashfs-root/lib/modules/privilege_ip.ko
# squashfs-root/lib/modules/GPL_NetUSB.ko
# squashfs-root/lib/modules/nls_cp950.ko
# squashfs-root/lib/modules/ufsd.ko
# squashfs-root/lib/modules/fastnat.ko
# squashfs-root/lib/modules/loadbalance.ko
# squashfs-root/lib/modules/nls_cp936.ko
# squashfs-root/lib/modules/nls_cp437.ko
# squashfs-root/lib/modules/app_filter.ko
# squashfs-root/lib/modules/jnl.ko
# squashfs-root/lib/modules/fastnat_configure.ko
# squashfs-root/lib/modules/mac_filter.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/
# squashfs-root/lib/modules/2.6.36.4brcmarm/source
# squashfs-root/lib/modules/2.6.36.4brcmarm/build
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/net/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/net/sched/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/net/sched/sch_hfsc.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/net/sched/sch_tbf.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/connector/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/connector/cn.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/class/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/class/cdc-acm.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/storage/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/storage/usb-storage.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/host/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/host/xhci-hcd.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/host/ohci-hcd.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/host/ehci-hcd.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/mon/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/mon/usbmon.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/serial/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/serial/sierra.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/serial/option.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/serial/usb_wwan.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/serial/usbserial.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/serial/usb_debug.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/misc/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/misc/usb_led_blink.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/core/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/usb/core/usbcore.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/proxyarp/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/proxyarp/proxyarp.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/usb/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/usb/zaurus.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/usb/net1080.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/usb/usbnet.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/usb/cdc_ether.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/usb/cdc_subset.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/usb/asix.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/dpsta/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/dpsta/dpsta.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/emf/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/emf/emf.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/wl/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/wl/wl.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/mii.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/et/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/et/et.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/igs/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/net/igs/igs.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/cdrom/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/cdrom/cdrom.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/scsi/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/scsi/sr_mod.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/drivers/scsi/scsi_wait_scan.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/arch/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/arch/arm/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/arch/arm/oprofile/
# squashfs-root/lib/modules/2.6.36.4brcmarm/kernel/arch/arm/oprofile/oprofile.ko
# squashfs-root/lib/modules/2.6.36.4brcmarm/modules.order
# squashfs-root/lib/modules/2.6.36.4brcmarm/modules.builtin
# squashfs-root/lib/modules/pptp.ko
# squashfs-root/lib/modules/ddos_ip_fence.ko
# squashfs-root/lib/modules/port_filter.ko
# squashfs-root/lib/modules/ip_mac_bind.ko
# squashfs-root/lib/modules/bm.ko
# squashfs-root/lib/modules/arp_fence.ko
# squashfs-root/lib/modules/url_filter.ko
# squashfs-root/lib/modules/qos.ko
# squashfs-root/lib/modules/NetUSB.ko
# squashfs-root/etc_ro/
# squashfs-root/etc_ro/shadow
# squashfs-root/etc_ro/udev/
# squashfs-root/etc_ro/udev/rules.d/
# squashfs-root/etc_ro/udev/rules.d/udev.rules
# squashfs-root/etc_ro/udev/udev.conf
# squashfs-root/etc_ro/group
# squashfs-root/etc_ro/mac_vendor.txt
# squashfs-root/etc_ro/policy_bak.cfg
# squashfs-root/etc_ro/nginx/
# squashfs-root/etc_ro/nginx/conf/
# squashfs-root/etc_ro/nginx/conf/uwsgi_params
# squashfs-root/etc_ro/nginx/conf/fastcgi_params
# squashfs-root/etc_ro/nginx/conf/fastcgi.conf
# squashfs-root/etc_ro/nginx/conf/scgi_params
# squashfs-root/etc_ro/nginx/conf/nginx.conf
# squashfs-root/etc_ro/nginx/conf/koi-win
# squashfs-root/etc_ro/nginx/conf/koi-utf
# squashfs-root/etc_ro/nginx/conf/win-utf
# squashfs-root/etc_ro/nginx/conf/nginx_init.sh
# squashfs-root/etc_ro/nginx/conf/mime.types
# squashfs-root/etc_ro/features.cfg
# squashfs-root/etc_ro/inittab
# squashfs-root/etc_ro/fstab
# squashfs-root/etc_ro/proto_class.txt
# squashfs-root/etc_ro/minidlna.conf
# squashfs-root/etc_ro/wds.sh
# squashfs-root/etc_ro/ld.so.cache
# squashfs-root/etc_ro/ppp/
# squashfs-root/etc_ro/ppp/plugins/
# squashfs-root/etc_ro/ppp/plugins/cmd.so
# squashfs-root/etc_ro/ppp/plugins/sync-pppd.so
# squashfs-root/etc_ro/init.d/
# squashfs-root/etc_ro/init.d/rcS
# squashfs-root/etc_ro/iproute2/
# squashfs-root/etc_ro/iproute2/rt_tables
# squashfs-root/etc_ro/fireversion.cfg
# squashfs-root/etc_ro/vsftpd.conf
# squashfs-root/etc_ro/smb.conf
# squashfs-root/etc_ro/printer_switch
# squashfs-root/etc_ro/vsftpd/
# squashfs-root/etc_ro/passwd
# squashfs-root/etc_ro/hotplug2.rules
# squashfs-root/etc_ro/HP_P1008.img
# squashfs-root/etc_ro/ld.so.conf
# squashfs-root/etc_ro/mdev.conf
# squashfs-root/tmp/
# squashfs-root/bin/
# squashfs-root/bin/xl2tpd_wan1
# squashfs-root/bin/cttyhack
# squashfs-root/bin/eapd
# squashfs-root/bin/logserver
# squashfs-root/bin/pptpc.sh
# squashfs-root/bin/dd
# squashfs-root/bin/ucloud_v2
# squashfs-root/bin/l2tpd
# squashfs-root/bin/msh
# squashfs-root/bin/pppoeconfig.sh
# squashfs-root/bin/httpd
# squashfs-root/bin/echo
# squashfs-root/bin/dnrd-wisp
# squashfs-root/bin/miniupnpd
# squashfs-root/bin/su
# squashfs-root/bin/more
# squashfs-root/bin/pptp_wan1
# squashfs-root/bin/phddns_wan2
# squashfs-root/bin/ip
# squashfs-root/bin/cp
# squashfs-root/bin/pppd_wan1
# squashfs-root/bin/mkdir
# squashfs-root/bin/pptpd
# squashfs-root/bin/dhcpcd_wan3
# squashfs-root/bin/cat
# squashfs-root/bin/p910nd
# squashfs-root/bin/touch
# squashfs-root/bin/dnrd-guest
# squashfs-root/bin/kill
# squashfs-root/bin/pptpc244.sh
# squashfs-root/bin/usleep
# squashfs-root/bin/wps_monitor
# squashfs-root/bin/igmpproxy
# squashfs-root/bin/business_proc
# squashfs-root/bin/88ip
# squashfs-root/bin/ping
# squashfs-root/bin/pptpd.sh
# squashfs-root/bin/moniter
# squashfs-root/bin/pptp_callmgr
# squashfs-root/bin/flash_erase
# squashfs-root/bin/xl2tpd_wan2
# squashfs-root/bin/pptp_wan4
# squashfs-root/bin/dmesg
# squashfs-root/bin/dhcpcd_wan4
# squashfs-root/bin/vi
# squashfs-root/bin/grep
# squashfs-root/bin/sh
# squashfs-root/bin/getopt
# squashfs-root/bin/phddns
# squashfs-root/bin/busybox
# squashfs-root/bin/ls
# squashfs-root/bin/l2tp-control
# squashfs-root/bin/login
# squashfs-root/bin/pppd_wan2
# squashfs-root/bin/xl2tpd_wan4
# squashfs-root/bin/rm
# squashfs-root/bin/auto_discover
# squashfs-root/bin/fdisk
# squashfs-root/bin/mv
# squashfs-root/bin/rmdir
# squashfs-root/bin/dhcpcd_lan
# squashfs-root/bin/wan_surf
# squashfs-root/bin/tar
# squashfs-root/bin/xl2tpcltpppd
# squashfs-root/bin/dhttpd
# squashfs-root/bin/lzma
# squashfs-root/bin/phddns_wan1
# squashfs-root/bin/sleep
# squashfs-root/bin/chkntfs
# squashfs-root/bin/envram
# squashfs-root/bin/pptpctrl
# squashfs-root/bin/df
# squashfs-root/bin/time_check
# squashfs-root/bin/unmkpkg
# squashfs-root/bin/tendaupload
# squashfs-root/bin/dhcpcd_wan2
# squashfs-root/bin/pppd
# squashfs-root/bin/minidlna
# squashfs-root/bin/wins
# squashfs-root/bin/sed
# squashfs-root/bin/ps
# squashfs-root/bin/inadyn
# squashfs-root/bin/pptppppd-server
# squashfs-root/bin/ash
# squashfs-root/bin/pwd
# squashfs-root/bin/emf
# squashfs-root/bin/chat
# squashfs-root/bin/multiWAN
# squashfs-root/bin/nvram
# squashfs-root/bin/dhcpcd
# squashfs-root/bin/netctrl
# squashfs-root/bin/ln
# squashfs-root/bin/unbzip2
# squashfs-root/bin/xl2tppppd
# squashfs-root/bin/xl2tpd
# squashfs-root/bin/phddns_wan3
# squashfs-root/bin/dhcpcd_wan1
# squashfs-root/bin/dhcps
# squashfs-root/bin/pppd_wan4
# squashfs-root/bin/sntp
# squashfs-root/bin/umount
# squashfs-root/bin/pptppppd
# squashfs-root/bin/mount
# squashfs-root/bin/ping6
# squashfs-root/bin/netstat
# squashfs-root/bin/pptp_wan3
# squashfs-root/bin/cfm
# squashfs-root/bin/uname
# squashfs-root/bin/upgrade
# squashfs-root/bin/3322ip
# squashfs-root/bin/date
# squashfs-root/bin/hush
# squashfs-root/bin/dosfsck
# squashfs-root/bin/alibaba_update
# squashfs-root/bin/query_version
# squashfs-root/bin/dhcps-guest
# squashfs-root/bin/tendauploadcfe
# squashfs-root/bin/pptpd244.sh
# squashfs-root/bin/pptp_wan2
# squashfs-root/bin/xl2tpd_wan3
# squashfs-root/bin/speedtest
# squashfs-root/bin/cfmd
# squashfs-root/bin/taskset
# squashfs-root/bin/pppd_wan3
# squashfs-root/bin/bcrelay
# squashfs-root/bin/phddns_wan4
# squashfs-root/bin/dnrd
# squashfs-root/bin/vsftpd
# squashfs-root/bin/mknod
# squashfs-root/bin/iprule.sh
# squashfs-root/bin/true
# squashfs-root/bin/pptp
# squashfs-root/bin/igs
# squashfs-root/bin/false
# squashfs-root/bin/chmod
# squashfs-root/bin/xl2tpd-server
# squashfs-root/usr/
# squashfs-root/usr/lib/
# squashfs-root/usr/lib/libnetfilter_conntrack.la
# squashfs-root/usr/lib/libnetfilter_queue.la
# squashfs-root/usr/lib/libip4tc.so
# squashfs-root/usr/lib/libiptc.so.0.0.0
# squashfs-root/usr/lib/libmnl.la
# squashfs-root/usr/lib/libmnl.so
# squashfs-root/usr/lib/libmnl.so.0.1.0
# squashfs-root/usr/lib/libnfnetlink.so
# squashfs-root/usr/lib/libnetfilter_conntrack.so.3
# squashfs-root/usr/lib/libnetfilter_conntrack.so
# squashfs-root/usr/lib/libxtables.so.7
# squashfs-root/usr/lib/libip6tc.la
# squashfs-root/usr/lib/libiptc.so
# squashfs-root/usr/lib/pkgconfig/
# squashfs-root/usr/lib/pkgconfig/xtables.pc
# squashfs-root/usr/lib/pkgconfig/libip4tc.pc
# squashfs-root/usr/lib/pkgconfig/libiptc.pc
# squashfs-root/usr/lib/pkgconfig/libip6tc.pc
# squashfs-root/usr/lib/libnetfilter_conntrack.so.3.4.0
# squashfs-root/usr/lib/libxtables.so.7.0.0
# squashfs-root/usr/lib/libnfnetlink.la
# squashfs-root/usr/lib/libip4tc.la
# squashfs-root/usr/lib/libip4tc.so.0.0.0
# squashfs-root/usr/lib/libiptc.la
# squashfs-root/usr/lib/libnetfilter_queue.so
# squashfs-root/usr/lib/xtables/
# squashfs-root/usr/lib/libnfnetlink.so.0
# squashfs-root/usr/lib/libiptc.so.0
# squashfs-root/usr/lib/libmnl.so.0
# squashfs-root/usr/lib/libstdc++.so.6.0.14
# squashfs-root/usr/lib/libip4tc.so.0
# squashfs-root/usr/lib/libxtables.la
# squashfs-root/usr/lib/libstdc++.so.6
# squashfs-root/usr/lib/libip6tc.so
# squashfs-root/usr/lib/libnetfilter_queue.so.1
# squashfs-root/usr/lib/libnetconf.so
# squashfs-root/usr/lib/libip6tc.so.0
# squashfs-root/usr/lib/libnetfilter_queue.so.1.3.0
# squashfs-root/usr/lib/libnfnetlink.so.0.2.0
# squashfs-root/usr/lib/libip6tc.so.0.0.0
# squashfs-root/usr/tmp
# squashfs-root/usr/bin/
# squashfs-root/usr/bin/xargs
# squashfs-root/usr/bin/dirname
# squashfs-root/usr/bin/find
# squashfs-root/usr/bin/head
# squashfs-root/usr/bin/[[
# squashfs-root/usr/bin/id
# squashfs-root/usr/bin/traceroute
# squashfs-root/usr/bin/logger
# squashfs-root/usr/bin/hostid
# squashfs-root/usr/bin/mkfifo
# squashfs-root/usr/bin/wc
# squashfs-root/usr/bin/nginx
# squashfs-root/usr/bin/spawn-fcgi
# squashfs-root/usr/bin/du
# squashfs-root/usr/bin/printf
# squashfs-root/usr/bin/which
# squashfs-root/usr/bin/sync
# squashfs-root/usr/bin/reset
# squashfs-root/usr/bin/cut
# squashfs-root/usr/bin/cryptpw
# squashfs-root/usr/bin/hd
# squashfs-root/usr/bin/top
# squashfs-root/usr/bin/mesg
# squashfs-root/usr/bin/unzip
# squashfs-root/usr/bin/vmstat
# squashfs-root/usr/bin/clear
# squashfs-root/usr/bin/killall5
# squashfs-root/usr/bin/wget
# squashfs-root/usr/bin/tail
# squashfs-root/usr/bin/less
# squashfs-root/usr/bin/arping
# squashfs-root/usr/bin/nslookup
# squashfs-root/usr/bin/test
# squashfs-root/usr/bin/tftp
# squashfs-root/usr/bin/yes
# squashfs-root/usr/bin/awk
# squashfs-root/usr/bin/free
# squashfs-root/usr/bin/ipcs
# squashfs-root/usr/bin/telnet
# squashfs-root/usr/bin/diff
# squashfs-root/usr/bin/basename
# squashfs-root/usr/bin/env
# squashfs-root/usr/bin/uptime
# squashfs-root/usr/bin/expr
# squashfs-root/usr/bin/killall
# squashfs-root/usr/bin/passwd
# squashfs-root/usr/bin/tr
# squashfs-root/usr/bin/[
# squashfs-root/usr/bin/app_data_center
# squashfs-root/usr/bin/hexdump
# squashfs-root/usr/local/
# squashfs-root/usr/local/udhcpc/
# squashfs-root/usr/local/udhcpc/sample.bound
# squashfs-root/usr/local/udhcpc/sample.renew
# squashfs-root/usr/local/udhcpc/sample.nak
# squashfs-root/usr/local/udhcpc/sample.info
# squashfs-root/usr/local/udhcpc/sample.deconfig
# squashfs-root/usr/local/udhcpc/sample.script
# squashfs-root/usr/local/ssl/
# squashfs-root/usr/local/ssl/openssl.cnf
# squashfs-root/usr/local/vsftpd/
# squashfs-root/usr/sbin/
# squashfs-root/usr/sbin/udhcpc
# squashfs-root/usr/sbin/usb_down.sh
# squashfs-root/usr/sbin/brctl
# squashfs-root/usr/sbin/smbpasswd
# squashfs-root/usr/sbin/ip6tables
# squashfs-root/usr/sbin/iptables
# squashfs-root/usr/sbin/iptables-save
# squashfs-root/usr/sbin/ip6tables-restore
# squashfs-root/usr/sbin/usb_up.sh
# squashfs-root/usr/sbin/Printer.sh
# squashfs-root/usr/sbin/wlconf
# squashfs-root/usr/sbin/dnsmasq
# squashfs-root/usr/sbin/ip6tables-save
# squashfs-root/usr/sbin/udhcpd
# squashfs-root/usr/sbin/comad
# squashfs-root/usr/sbin/nas
# squashfs-root/usr/sbin/pptpctrl
# squashfs-root/usr/sbin/acsd
# squashfs-root/usr/sbin/telnetd
# squashfs-root/usr/sbin/wl
# squashfs-root/usr/sbin/td_acs_dbg
# squashfs-root/usr/sbin/pppoecd
# squashfs-root/usr/sbin/xtables-multi
# squashfs-root/usr/sbin/smbd
# squashfs-root/usr/sbin/et
# squashfs-root/usr/sbin/iptables-restore
# squashfs-root/usr/sbin/rdate
# squashfs-root/cfg/
# squashfs-root/cfg/mib.cfg
# squashfs-root/cfg/mib_backup.cfg
# squashfs-root/dev/
# squashfs-root/dev/ttyS0
# tar: squashfs-root/dev/ttyS0: Cannot mknod: Operation not permitted
# squashfs-root/dev/console
# tar: squashfs-root/dev/console: Cannot mknod: Operation not permitted
# squashfs-root/dev/ttyS1
# tar: squashfs-root/dev/ttyS1: Cannot mknod: Operation not permitted
# squashfs-root/webroot_ro/
# squashfs-root/webroot_ro/system_status.html
# squashfs-root/webroot_ro/iptv.html
# squashfs-root/webroot_ro/samba.html
# squashfs-root/webroot_ro/wireless_ssid.html
# squashfs-root/webroot_ro/err_noWan.html
# squashfs-root/webroot_ro/cloud_managment.html
# squashfs-root/webroot_ro/wifi_wps.html
# squashfs-root/webroot_ro/main.html
# squashfs-root/webroot_ro/wifi_bf.html
# squashfs-root/webroot_ro/dmz.html
# squashfs-root/webroot_ro/redirect.html
# squashfs-root/webroot_ro/printer.html
# squashfs-root/webroot_ro/css/
# squashfs-root/webroot_ro/css/reasy-ui.css
# squashfs-root/webroot_ro/css/ie6.css
# squashfs-root/webroot_ro/css/test.css
# squashfs-root/webroot_ro/system_automaintain.html
# squashfs-root/webroot_ro/mac_clone.html
# squashfs-root/webroot_ro/system_led.html
# squashfs-root/webroot_ro/nvram_default.cfg
# squashfs-root/webroot_ro/network-diagnose.html
# squashfs-root/webroot_ro/pptp_client.html
# squashfs-root/webroot_ro/system_log.html
# squashfs-root/webroot_ro/err_pppoe_timeout.html
# squashfs-root/webroot_ro/directupgrade.html
# squashfs-root/webroot_ro/online_list.html
# squashfs-root/webroot_ro/wisp.html
# squashfs-root/webroot_ro/wireless_access.html
# squashfs-root/webroot_ro/loginerr.html
# squashfs-root/webroot_ro/err_account.html
# squashfs-root/webroot_ro/img/
# squashfs-root/webroot_ro/img/wifi-line-gray.png
# squashfs-root/webroot_ro/img/wifi_cover.png
# squashfs-root/webroot_ro/img/no-usb.png
# squashfs-root/webroot_ro/img/btn_off.png
# squashfs-root/webroot_ro/img/wifi-white.png
# squashfs-root/webroot_ro/img/usb_small.png
# squashfs-root/webroot_ro/img/tenda_code.png
# squashfs-root/webroot_ro/img/internet.png
# squashfs-root/webroot_ro/img/ali_code.png
# squashfs-root/webroot_ro/img/wifi-gray.png
# squashfs-root/webroot_ro/img/net-speed-bg.jpg
# squashfs-root/webroot_ro/img/internet-warning.png
# squashfs-root/webroot_ro/img/wifi-extender.png
# squashfs-root/webroot_ro/img/wifi-open.png
# squashfs-root/webroot_ro/img/logo-gray.png
# squashfs-root/webroot_ro/img/logo.png
# squashfs-root/webroot_ro/img/unbind_hilight.png
# squashfs-root/webroot_ro/img/icon-status-online.png
# squashfs-root/webroot_ro/img/router1_images2.gif
# squashfs-root/webroot_ro/img/qos.png
# squashfs-root/webroot_ro/img/new-version.png
# squashfs-root/webroot_ro/img/security-info.png
# squashfs-root/webroot_ro/img/ok_connected.png
# squashfs-root/webroot_ro/img/text_box_normal.png
# squashfs-root/webroot_ro/img/index-status-on.png
# squashfs-root/webroot_ro/img/validatebox_arrows.png
# squashfs-root/webroot_ro/img/icon-cloud.png
# squashfs-root/webroot_ro/img/main-logo.png
# squashfs-root/webroot_ro/img/internet-ok.png
# squashfs-root/webroot_ro/img/text_box_hover.png
# squashfs-root/webroot_ro/img/icon-power.png
# squashfs-root/webroot_ro/img/icon-power-gray1.png
# squashfs-root/webroot_ro/img/online_edit.png
# squashfs-root/webroot_ro/img/wan-info.png
# squashfs-root/webroot_ro/img/refresh.png
# squashfs-root/webroot_ro/img/edit_new.png
# squashfs-root/webroot_ro/img/round-line.png
# squashfs-root/webroot_ro/img/edit.png
# squashfs-root/webroot_ro/img/x_lables.png
# squashfs-root/webroot_ro/img/icon-power-gray2.png
# squashfs-root/webroot_ro/img/folder.png
# squashfs-root/webroot_ro/img/upper-router.png
# squashfs-root/webroot_ro/img/enable_hilight.png
# squashfs-root/webroot_ro/img/internet-connectting.png
# squashfs-root/webroot_ro/img/lock32.png
# squashfs-root/webroot_ro/img/wifi-line-up.png
# squashfs-root/webroot_ro/img/disable.png
# squashfs-root/webroot_ro/img/loading-round.gif
# squashfs-root/webroot_ro/img/code.png
# squashfs-root/webroot_ro/img/wifi-connect-disable.png
# squashfs-root/webroot_ro/img/wifi-connect.png
# squashfs-root/webroot_ro/img/line.png
# squashfs-root/webroot_ro/img/icon-beamfoming.png
# squashfs-root/webroot_ro/img/downspeed.png
# squashfs-root/webroot_ro/img/icon-pwd.png
# squashfs-root/webroot_ro/img/edit_new_hilight.png
# squashfs-root/webroot_ro/img/user.png
# squashfs-root/webroot_ro/img/shadow.jpg
# squashfs-root/webroot_ro/img/internet-disable.png
# squashfs-root/webroot_ro/img/advance-info.png
# squashfs-root/webroot_ro/img/square.png
# squashfs-root/webroot_ro/img/router.png
# squashfs-root/webroot_ro/img/thunder.png
# squashfs-root/webroot_ro/img/btn_en.png
# squashfs-root/webroot_ro/img/selected.png
# squashfs-root/webroot_ro/img/loading-upgrade.gif
# squashfs-root/webroot_ro/img/internet-disable-line.png
# squashfs-root/webroot_ro/img/unbind.png
# squashfs-root/webroot_ro/img/menu_info.png
# squashfs-root/webroot_ro/img/menu-active.png
# squashfs-root/webroot_ro/img/u1949.png
# squashfs-root/webroot_ro/img/icon-usb-device.png
# squashfs-root/webroot_ro/img/online.png
# squashfs-root/webroot_ro/img/device/
# squashfs-root/webroot_ro/img/device/pc.png
# squashfs-root/webroot_ro/img/device/smartisan.png
# squashfs-root/webroot_ro/img/device/coolpad.png
# squashfs-root/webroot_ro/img/device/huawei.png
# squashfs-root/webroot_ro/img/device/aino.png
# squashfs-root/webroot_ro/img/device/philips.png
# squashfs-root/webroot_ro/img/device/oppo.png
# squashfs-root/webroot_ro/img/device/vivo.png
# squashfs-root/webroot_ro/img/device/google.png
# squashfs-root/webroot_ro/img/device/ktouch.png
# squashfs-root/webroot_ro/img/device/others.png
# squashfs-root/webroot_ro/img/device/zte.png
# squashfs-root/webroot_ro/img/device/asus.png
# squashfs-root/webroot_ro/img/device/sonyericsson.png
# squashfs-root/webroot_ro/img/device/amoi.png
# squashfs-root/webroot_ro/img/device/lg.png
# squashfs-root/webroot_ro/img/device/xiaomi.png
# squashfs-root/webroot_ro/img/device/samsung.png
# squashfs-root/webroot_ro/img/device/meizu.png
# squashfs-root/webroot_ro/img/device/nubia.png
# squashfs-root/webroot_ro/img/device/leshi.png
# squashfs-root/webroot_ro/img/device/moto.png
# squashfs-root/webroot_ro/img/device/sony.png
# squashfs-root/webroot_ro/img/device/unknown.png
# squashfs-root/webroot_ro/img/device/gionee.png
# squashfs-root/webroot_ro/img/device/nokia.png
# squashfs-root/webroot_ro/img/device/apple.png
# squashfs-root/webroot_ro/img/device/oneplus.png
# squashfs-root/webroot_ro/img/device/acer.png
# squashfs-root/webroot_ro/img/device/tcl.png
# squashfs-root/webroot_ro/img/device/tenda.png
# squashfs-root/webroot_ro/img/device/hisense.png
# squashfs-root/webroot_ro/img/device/lenovo.png
# squashfs-root/webroot_ro/img/device/arnova.png
# squashfs-root/webroot_ro/img/device/tp-link.png
# squashfs-root/webroot_ro/img/device/amazon.png
# squashfs-root/webroot_ro/img/device/htc.png
# squashfs-root/webroot_ro/img/ico-extender.png
# squashfs-root/webroot_ro/img/wifi-coverag.png
# squashfs-root/webroot_ro/img/index-logo.png
# squashfs-root/webroot_ro/img/main_logo.png
# squashfs-root/webroot_ro/img/icon-usb.png
# squashfs-root/webroot_ro/img/disable_hilight.png
# squashfs-root/webroot_ro/img/power_img.png
# squashfs-root/webroot_ro/img/delete_hilight.png
# squashfs-root/webroot_ro/img/close.png
# squashfs-root/webroot_ro/img/upspeed.png
# squashfs-root/webroot_ro/img/offline.png
# squashfs-root/webroot_ro/img/logo_bule.png
# squashfs-root/webroot_ro/img/ok.png
# squashfs-root/webroot_ro/img/loading.gif
# squashfs-root/webroot_ro/img/enable.png
# squashfs-root/webroot_ro/img/power.png
# squashfs-root/webroot_ro/img/circle.png
# squashfs-root/webroot_ro/img/speed_dis.png
# squashfs-root/webroot_ro/img/internet.gif
# squashfs-root/webroot_ro/img/main_title.png
# squashfs-root/webroot_ro/img/bg.png
# squashfs-root/webroot_ro/img/diagnose-internet.png
# squashfs-root/webroot_ro/img/line-off.png
# squashfs-root/webroot_ro/img/router1_images3.png
# squashfs-root/webroot_ro/img/bind_hilight.png
# squashfs-root/webroot_ro/img/advance-info-dmz.png
# squashfs-root/webroot_ro/img/hdd.png
# squashfs-root/webroot_ro/img/delete.png
# squashfs-root/webroot_ro/img/wifi_strength.png
# squashfs-root/webroot_ro/img/round.png
# squashfs-root/webroot_ro/img/scan.gif
# squashfs-root/webroot_ro/img/line-on.png
# squashfs-root/webroot_ro/img/internet_connectting.gif
# squashfs-root/webroot_ro/img/yun-info.png
# squashfs-root/webroot_ro/img/online-list.png
# squashfs-root/webroot_ro/img/wifiname.png
# squashfs-root/webroot_ro/img/round-gray.png
# squashfs-root/webroot_ro/img/warning-info.png
# squashfs-root/webroot_ro/img/open.png
# squashfs-root/webroot_ro/img/progress.png
# squashfs-root/webroot_ro/img/password.png
# squashfs-root/webroot_ro/img/icon-online.png
# squashfs-root/webroot_ro/img/country.png
# squashfs-root/webroot_ro/img/select-info-left.png
# squashfs-root/webroot_ro/img/buy.png
# squashfs-root/webroot_ro/img/ali_adv_code.png
# squashfs-root/webroot_ro/img/bind.png
# squashfs-root/webroot_ro/img/icon-status-offline.png
# squashfs-root/webroot_ro/img/logo-white.png
# squashfs-root/webroot_ro/img/select-info.png
# squashfs-root/webroot_ro/login.html
# squashfs-root/webroot_ro/parental_control.html
# squashfs-root/webroot_ro/ap_diagnosis.html
# squashfs-root/webroot_ro/pptp_user.html
# squashfs-root/webroot_ro/xunleiDownload.html
# squashfs-root/webroot_ro/system_reboot.html
# squashfs-root/webroot_ro/system_config.html
# squashfs-root/webroot_ro/virtual_server.html
# squashfs-root/webroot_ro/dhcp_server.html
# squashfs-root/webroot_ro/wifi_time.html
# squashfs-root/webroot_ro/static_route.html
# squashfs-root/webroot_ro/wifi_signal.html
# squashfs-root/webroot_ro/black_list.html
# squashfs-root/webroot_ro/pem/
# squashfs-root/webroot_ro/pem/privkeySrv.pem
# squashfs-root/webroot_ro/pem/certSrv.crt
# squashfs-root/webroot_ro/favicon.ico
# squashfs-root/webroot_ro/pptp_server.html
# squashfs-root/webroot_ro/wifi_power.html
# squashfs-root/webroot_ro/ip_mac_bind.html
# squashfs-root/webroot_ro/ddns_config.html
# squashfs-root/webroot_ro/mac_filter.html
# squashfs-root/webroot_ro/sleep_mode.html
# squashfs-root/webroot_ro/js/
# squashfs-root/webroot_ro/js/samba.js
# squashfs-root/webroot_ro/js/login.js
# squashfs-root/webroot_ro/js/iptv.js
# squashfs-root/webroot_ro/js/index.js
# squashfs-root/webroot_ro/js/dmz.js
# squashfs-root/webroot_ro/js/pptp_client.js
# squashfs-root/webroot_ro/js/yun_safe.js
# squashfs-root/webroot_ro/js/wireless_access.js
# squashfs-root/webroot_ro/js/cloud_management.js
# squashfs-root/webroot_ro/js/thunder.js
# squashfs-root/webroot_ro/js/wifi_wps.js
# squashfs-root/webroot_ro/js/wisp.js
# squashfs-root/webroot_ro/js/system_automaintain.js
# squashfs-root/webroot_ro/js/net_control.js
# squashfs-root/webroot_ro/js/parental_control.js
# squashfs-root/webroot_ro/js/error_account.js
# squashfs-root/webroot_ro/js/system_led.js
# squashfs-root/webroot_ro/js/warning.js
# squashfs-root/webroot_ro/js/net_set.js
# squashfs-root/webroot_ro/js/wifi_power.js
# squashfs-root/webroot_ro/js/system_status.js
# squashfs-root/webroot_ro/js/virtual_server.js
# squashfs-root/webroot_ro/js/wireless_ssid.js
# squashfs-root/webroot_ro/js/pptp_user.js
# squashfs-root/webroot_ro/js/dlna.js
# squashfs-root/webroot_ro/js/network-diagnose.js
# squashfs-root/webroot_ro/js/macro_config.js
# squashfs-root/webroot_ro/js/lan.js
# squashfs-root/webroot_ro/js/firewall.js
# squashfs-root/webroot_ro/js/printer.js
# squashfs-root/webroot_ro/js/system.js
# squashfs-root/webroot_ro/js/ddns_config.js
# squashfs-root/webroot_ro/js/wifi_time.js
# squashfs-root/webroot_ro/js/dhcp_server.js
# squashfs-root/webroot_ro/js/libs/
# squashfs-root/webroot_ro/js/libs/public.js
# squashfs-root/webroot_ro/js/libs/ajaxfileupload.js
# squashfs-root/webroot_ro/js/libs/ZeroClipboard.swf
# squashfs-root/webroot_ro/js/libs/drager_zzc.js
# squashfs-root/webroot_ro/js/libs/jquery.easing.1.3.js
# squashfs-root/webroot_ro/js/libs/reasy-ui-1.0.3.js
# squashfs-root/webroot_ro/js/libs/md5.js
# squashfs-root/webroot_ro/js/libs/jquery.zclip.min.js
# squashfs-root/webroot_ro/js/libs/pagination.js
# squashfs-root/webroot_ro/js/libs/j.js
# squashfs-root/webroot_ro/js/libs/jquery.mousewheel.min.js
# squashfs-root/webroot_ro/js/libs/DD_belatedPNG_0.0.8a-min.js
# squashfs-root/webroot_ro/js/libs/html5shiv.js
# squashfs-root/webroot_ro/js/system_time.js
# squashfs-root/webroot_ro/js/remote_web.js
# squashfs-root/webroot_ro/js/black_list.js
# squashfs-root/webroot_ro/js/directupgrade.js
# squashfs-root/webroot_ro/js/upnp_config.js
# squashfs-root/webroot_ro/js/status_usb.js
# squashfs-root/webroot_ro/js/sleep_mode.js
# squashfs-root/webroot_ro/js/pptp_server.js
# squashfs-root/webroot_ro/js/system_log.js
# squashfs-root/webroot_ro/js/online_list.js
# squashfs-root/webroot_ro/js/mac_filter.js
# squashfs-root/webroot_ro/js/static_route.js
# squashfs-root/webroot_ro/js/wifi_bf.js
# squashfs-root/webroot_ro/js/wifi_ap.js
# squashfs-root/webroot_ro/js/wireless.js
# squashfs-root/webroot_ro/js/main.js
# squashfs-root/webroot_ro/js/ip_mac_bind.js
# squashfs-root/webroot_ro/js/xunleiDownload.js
# squashfs-root/webroot_ro/js/mac_clone.js
# squashfs-root/webroot_ro/system_upgrade.html
# squashfs-root/webroot_ro/system_password.html
# squashfs-root/webroot_ro/system_time.html
# squashfs-root/webroot_ro/wireless.html
# squashfs-root/webroot_ro/status_extender.html
# squashfs-root/webroot_ro/dlna.html
# squashfs-root/webroot_ro/err_dhcp_timeout.html
# squashfs-root/webroot_ro/remote_web.html
# squashfs-root/webroot_ro/index.html
# squashfs-root/webroot_ro/firewall.html
# squashfs-root/webroot_ro/default_url.cfg
# squashfs-root/webroot_ro/wan_status.html
# squashfs-root/webroot_ro/net_control.html
# squashfs-root/webroot_ro/simple_upgrade.asp
# squashfs-root/webroot_ro/status_usb.html
# squashfs-root/webroot_ro/system_restore.html
# squashfs-root/webroot_ro/lan.html
# squashfs-root/webroot_ro/net_set.html
# squashfs-root/webroot_ro/default.cfg
# squashfs-root/webroot_ro/upnp_config.html
# squashfs-root/webroot_ro/wifi_ap.html
# squashfs-root/webroot_ro/goform/
# squashfs-root/webroot_ro/goform/getMacFilterCfg.txt
# squashfs-root/webroot_ro/goform/SetVirtualServerCfg.txt
# squashfs-root/webroot_ro/goform/GetPptpClientCfg.txt
# squashfs-root/webroot_ro/goform/setThundercfg.txt
# squashfs-root/webroot_ro/goform/GetDDNSCfg.txt
# squashfs-root/webroot_ro/goform/setApModeCfg.txt
# squashfs-root/webroot_ro/goform/SetSambaCfg.txt
# squashfs-root/webroot_ro/goform/SetPrinterCfg.txt
# squashfs-root/webroot_ro/goform/expandDlnaFile.txt
# squashfs-root/webroot_ro/goform/fast_setting_internet_set.txt
# squashfs-root/webroot_ro/goform/GetSysStatus.txt
# squashfs-root/webroot_ro/goform/SetUpnpCfg.txt
# squashfs-root/webroot_ro/goform/fast_setting_pppoe_set.txt
# squashfs-root/webroot_ro/goform/cloudv2
# squashfs-root/webroot_ro/goform/GetSystemStatus.txt
# squashfs-root/webroot_ro/goform/WifiWpsSet.txt
# squashfs-root/webroot_ro/goform/GetSysTimeCfg.txt
# squashfs-root/webroot_ro/goform/PowerSaveGet.txt
# squashfs-root/webroot_ro/goform/SetIpMacBind.txt
# squashfs-root/webroot_ro/goform/SetSysTimeCfg.txt
# squashfs-root/webroot_ro/goform/SetDMZCfg.txt
# squashfs-root/webroot_ro/goform/getWanConnectStatus.txt
# squashfs-root/webroot_ro/goform/getThundercfg.txt
# squashfs-root/webroot_ro/goform/GetRemoteWebCfg.txt
# squashfs-root/webroot_ro/goform/WifiGuestGet.txt
# squashfs-root/webroot_ro/goform/GetParentCtrlList.txt
# squashfs-root/webroot_ro/goform/GetIpMacBind.txt
# squashfs-root/webroot_ro/goform/GetNetErrInfo.txt
# squashfs-root/webroot_ro/goform/UploadCfg.txt
# squashfs-root/webroot_ro/goform/SetStaticRouteCfg.txt
# squashfs-root/webroot_ro/goform/GetVPNList.txt
# squashfs-root/webroot_ro/goform/GetWrlStatus.txt
# squashfs-root/webroot_ro/goform/getWanParameters.txt
# squashfs-root/webroot_ro/goform/delBlackRule.txt
# squashfs-root/webroot_ro/goform/saveParentControlInfo.txt
# squashfs-root/webroot_ro/goform/setBlackRule.txt
# squashfs-root/webroot_ro/goform/SetSysAutoRebbotCfg.txt
# squashfs-root/webroot_ro/goform/WifiApScan.txt
# squashfs-root/webroot_ro/goform/GetDMZCfg.txt
# squashfs-root/webroot_ro/goform/setPptServerList.txt
# squashfs-root/webroot_ro/goform/GetDlnaCfg.txt
# squashfs-root/webroot_ro/goform/GetVirtualServerCfg.txt
# squashfs-root/webroot_ro/goform/SetIPTVCfg.txt
# squashfs-root/webroot_ro/goform/SetPptpClientCfg.txt
# squashfs-root/webroot_ro/goform/WifiBasicGet.txt
# squashfs-root/webroot_ro/goform/WifiGuestSet.txt
# squashfs-root/webroot_ro/goform/GetPptpServerCfg.txt
# squashfs-root/webroot_ro/goform/onlineupgrade.txt
# squashfs-root/webroot_ro/goform/GetSySLogCfg.txt
# squashfs-root/webroot_ro/goform/SetLEDCfg.txt
# squashfs-root/webroot_ro/goform/getOnlineUpgradeInfo.txt
# squashfs-root/webroot_ro/goform/WifiCoverageGet.txt
# squashfs-root/webroot_ro/goform/WifiPowerGet.txt
# squashfs-root/webroot_ro/goform/SetDDNSCfg.txt
# squashfs-root/webroot_ro/goform/SetNetControlList.txt
# squashfs-root/webroot_ro/goform/GetStaticRouteCfg.txt
# squashfs-root/webroot_ro/goform/setPptpUserList.txt
# squashfs-root/webroot_ro/goform/WifiExtraGet.txt
# squashfs-root/webroot_ro/goform/SetPptpServerCfg.txt
# squashfs-root/webroot_ro/goform/WifiBasicSet.txt
# squashfs-root/webroot_ro/goform/AdvSetMacMtuWan.txt
# squashfs-root/webroot_ro/goform/fast_setting_get.txt
# squashfs-root/webroot_ro/goform/cloud.txt
# squashfs-root/webroot_ro/goform/getOnlineList.txt
# squashfs-root/webroot_ro/goform/WifiRadioGet.txt
# squashfs-root/webroot_ro/goform/delParentalRule.txt
# squashfs-root/webroot_ro/goform/AdvSetLanip.txt
# squashfs-root/webroot_ro/goform/WifiBeamformingSet.txt
# squashfs-root/webroot_ro/goform/setMacFilterCfg.txt
# squashfs-root/webroot_ro/goform/GetFirewallCfg.txt
# squashfs-root/webroot_ro/goform/PowerSaveSet.txt
# squashfs-root/webroot_ro/goform/GetSysAutoRebbotCfg.txt
# squashfs-root/webroot_ro/goform/AdvGetMacMtuWan.txt
# squashfs-root/webroot_ro/goform/getHomeLink.txt
# squashfs-root/webroot_ro/goform/WifiCoverageSet.txt
# squashfs-root/webroot_ro/goform/GetUSBStatus.txt
# squashfs-root/webroot_ro/goform/GetRouterStatus.txt
# squashfs-root/webroot_ro/goform/getPptpOnlineClient.txt
# squashfs-root/webroot_ro/goform/initSchedWifi.txt
# squashfs-root/webroot_ro/goform/WifiWpsGet.txt
# squashfs-root/webroot_ro/goform/.htaccess
# squashfs-root/webroot_ro/goform/SysToolChangePwd.txt
# squashfs-root/webroot_ro/goform/AdvGetLanIp.txt
# squashfs-root/webroot_ro/goform/SysToolpassword.txt
# squashfs-root/webroot_ro/goform/GetParentControlInfo.txt
# squashfs-root/webroot_ro/goform/WifiRadioSet.txt
# squashfs-root/webroot_ro/goform/SetDeviceName.txt
# squashfs-root/webroot_ro/goform/GetUsbCfg.txt
# squashfs-root/webroot_ro/goform/fast_setting_wifi_set.txt
# squashfs-root/webroot_ro/goform/GetPrinterCfg.txt
# squashfs-root/webroot_ro/goform/GetLEDCfg.txt
# squashfs-root/webroot_ro/goform/SetOnlineDevName.txt
# squashfs-root/webroot_ro/goform/GetAdvanceStatus.txt
# squashfs-root/webroot_ro/goform/WanParameterSetting.txt
# squashfs-root/webroot_ro/goform/WifiWpsStart.txt
# squashfs-root/webroot_ro/goform/SetRemoteWebCfg.txt
# squashfs-root/webroot_ro/goform/SysToolReboot.txt
# squashfs-root/webroot_ro/goform/WifiPowerSet.txt
# squashfs-root/webroot_ro/goform/openSchedWifi.txt
# squashfs-root/webroot_ro/goform/getProduct.txt
# squashfs-root/webroot_ro/goform/GetSambaCfg.txt
# squashfs-root/webroot_ro/goform/parentControlEn.txt
# squashfs-root/webroot_ro/goform/GetIPTVCfg.txt
# squashfs-root/webroot_ro/goform/GetVpnStatus.txt
# squashfs-root/webroot_ro/goform/NoNotify.txt
# squashfs-root/webroot_ro/goform/WifiBeamformingGet.txt
# squashfs-root/webroot_ro/goform/GetUpnpCfg.txt
# squashfs-root/webroot_ro/goform/getBlackRuleList.txt
# squashfs-root/webroot_ro/goform/WifiExtraSet.txt
# squashfs-root/webroot_ro/goform/getApModeCfg.txt
# squashfs-root/webroot_ro/goform/GetNetControlList.txt
# squashfs-root/webroot_ro/goform/SysToolGetUpgrade.txt
# squashfs-root/webroot_ro/goform/SetDlnaCfg.txt
# squashfs-root/webroot_ro/goform/setUsbUnload.txt
# squashfs-root/webroot_ro/goform/setNotUpgrade.txt
# squashfs-root/webroot_ro/goform/getRebootStatus.txt
# squashfs-root/webroot_ro/lang/
# squashfs-root/webroot_ro/lang/en/
# squashfs-root/webroot_ro/lang/b28n_async.js
# squashfs-root/webroot_ro/lang/zh/
# squashfs-root/webroot_ro/lang/zh/translate.json
# squashfs-root/webroot_ro/lang/cn/
# squashfs-root/webroot_ro/lang/cn/translate.json
# squashfs-root/webroot_ro/system_backup.html
# squashfs-root/init
# squashfs-root/root
# squashfs-root/sys/
# squashfs-root/home
# squashfs-root/webroot
# squashfs-root/etc
# squashfs-root/sbin/
# squashfs-root/sbin/slattach
# squashfs-root/sbin/lsmod
# squashfs-root/sbin/depmod
# squashfs-root/sbin/pivot_root
# squashfs-root/sbin/modprobe
# squashfs-root/sbin/getty
# squashfs-root/sbin/sysctl
# squashfs-root/sbin/syslogd
# squashfs-root/sbin/arp
# squashfs-root/sbin/ifconfig
# squashfs-root/sbin/reboot
# squashfs-root/sbin/insmod
# squashfs-root/sbin/makedevs
# squashfs-root/sbin/eject
# squashfs-root/sbin/logread
# squashfs-root/sbin/sulogin
# squashfs-root/sbin/init
# squashfs-root/sbin/udevd
# squashfs-root/sbin/route
# squashfs-root/sbin/mdev
# squashfs-root/sbin/rmmod
# squashfs-root/sbin/ping6
# squashfs-root/sbin/klogd
# squashfs-root/sbin/blkid
# squashfs-root/sbin/vconfig
# squashfs-root/sbin/halt
# squashfs-root/sbin/poweroff
# squashfs-root/mnt/
# squashfs-root/proc/
# squashfs-root/var/
# squashfs-root/var/root/
# squashfs-root/var/home/
# squashfs-root/var/webroot/
# squashfs-root/var/etc/
# tar: Exiting with failure status due to previous errors

# %%
# !mkdir ./AC15
# !cp ./squashfs-root/bin/httpd ./AC15/AC15_httpd
# !cp ./rootfs/usr/bin/webs ./AC15/TRI227WF_webs

# %%
# %%time
exe_path = "./AC15"
pyScript_path = "./"
tempProject = "./"
py_script = "./gheadless.py"
# Out:
# CPU times: user 10 μs, sys: 0 ns, total: 10 μs
# Wall time: 16.9 μs

# %%
# %%time
# !{ghidra_headless} {tempProject} TeamProject -import {exe_path} -analysisTimeoutPerFile 30  -scriptPath {pyScript_path} -postScript {py_script} -deleteProject -log my_log.txt
# Out:
# openjdk version "21.0.4" 2024-07-16
# OpenJDK Runtime Environment (build 21.0.4+7-Ubuntu-1ubuntu222.04)
# OpenJDK 64-Bit Server VM (build 21.0.4+7-Ubuntu-1ubuntu222.04, mixed mode)
# INFO  Using log config file: jar:file:/opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Framework/Generic/lib/Generic.jar!/generic.log4j.xml (LoggingInitialization)
# INFO  Using log file: my_log.txt (LoggingInitialization)
# INFO  Loading user preferences: /root/.config/ghidra/ghidra_11.1.2_PUBLIC/preferences (Preferences)
# INFO  Searching for classes... (ClassSearcher)
# INFO  Ignoring class 'generic.jar.GClassLoader' from '/opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Framework/Utility/lib/Utility.jar'. Already found at '/opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Framework/Utility/lib/Utility.jar'. (ClassSearcher)
# INFO  Ignoring class 'ghidra.GhidraClassLoader' from '/opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Framework/Utility/lib/Utility.jar'. Already found at '/opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Framework/Utility/lib/Utility.jar'. (ClassSearcher)
# INFO  Class search complete (1708 ms) (ClassSearcher)
# INFO  Initializing SSL Context (SSLContextInitializer)
# INFO  Initializing Random Number Generator... (SecureRandomFactory)
# INFO  Random Number Generator initialization complete: NativePRNGNonBlocking (SecureRandomFactory)
# INFO  Trust manager disabled, cacerts have not been set (ApplicationTrustManagerFactory)
# INFO  Starting cache cleanup: /var/tmp/root-ghidra/fscache2 (FileCacheMaintenanceDaemon)
# INFO  Finished cache cleanup, estimated storage used: 0 (FileCacheMaintenanceDaemon)
# INFO  Headless startup complete (3774 ms) (AnalyzeHeadless)
# INFO  Class searcher loaded 57 extension points (17 false positives) (ClassSearcher)
# INFO  HEADLESS Script Paths:
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Debug/Debugger/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Processors/PIC/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/PDB/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/FileFormats/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/VersionTracking/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/SwiftDemangler/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Debug/Debugger-rmi-trace/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/FunctionID/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Processors/DATA/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/Base/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/BytePatterns/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Processors/Atmel/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/SystemEmulation/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/Decompiler/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/BSim/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/MicrosoftCodeAnalyzer/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Processors/8051/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/Python/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Processors/JVM/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Debug/Debugger-agent-frida/ghidra_scripts
#     /local/.
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/GnuDemangler/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Debug/Debugger-agent-dbgmodel-traceloader/ghidra_scripts
#     /opt/src/ghidra_11.1.2_PUBLIC/Ghidra/Features/WildcardAssembler/ghidra_scripts (HeadlessAnalyzer)
# INFO  HEADLESS: execution starts (HeadlessAnalyzer)
# INFO  Creating temporary project: /local/./TeamProject (HeadlessAnalyzer)
# INFO  Creating project: /local/./TeamProject (DefaultProject)
# INFO  REPORT: Processing input files:  (HeadlessAnalyzer)
# INFO       project: /local/./TeamProject (HeadlessAnalyzer)
# INFO  IMPORTING: file:///local/AC15/AC15_httpd?MD5=35a3115eb9749638fd5e19c26c7fa752 (HeadlessAnalyzer)
# INFO  Using Loader: Executable and Linking Format (ELF) (AutoImporter)
# INFO  Using Language/Compiler: ARM:LE:32:v8:default (AutoImporter)
# INFO  Additional info:
# Loading file:///local/AC15/AC15_httpd?MD5=35a3115eb9749638fd5e19c26c7fa752...
# ------------------------------------------------
#
# Linking the External Programs of 'AC15_httpd' to imported libraries...
#   [libCfm.so] -> not found in project
#   [libcommon.so] -> not found in project
#   [libChipApi.so] -> not found in project
#   [libvos_util.so] -> not found in project
#   [libz.so] -> not found in project
#   [libpthread.so.0] -> not found in project
#   [libnvram.so] -> not found in project
#   [libshared.so] -> not found in project
#   [libtpi.so] -> not found in project
#   [libm.so.0] -> not found in project
#   [libucapi.so] -> not found in project
#   [libgcc_s.so.1] -> not found in project
#   [libc.so.0] -> not found in project
# ------------------------------------------------
#
# Resolving External Symbols of [/AC15/AC15_httpd] - 283 unresolved symbols, no external libraries configured - skipping
#  (AutoImporter)
# INFO  IMPORTING: Loaded 0 additional files (HeadlessAnalyzer)
# INFO  ANALYZING all memory and code: file:///local/AC15/AC15_httpd?MD5=35a3115eb9749638fd5e19c26c7fa752 (HeadlessAnalyzer)
# INFO  DWARF external debug information found: ExternalDebugInfo [filename=httpd.debug, crc=c5070102, hash=null] (ExternalDebugFileSectionProvider)
# INFO  Unable to find DWARF information, skipping DWARF analysis (DWARFAnalyzer)
# INFO  hit non-returning function, restarting decompiler switch analyzer later (DecompilerSwitchAnalyzer)
# INFO  -----------------------------------------------------
#     ARM Constant Reference Analyzer           17.092 secs
#     ARM Symbol                                 0.003 secs
#     Call-Fixup Installer                       0.015 secs
#     Create Function                            0.525 secs
#     DWARF                                      0.009 secs
#     Decompiler Switch Analysis                 5.781 secs
#     Decompiler Switch Analysis - One Time      5.742 secs
#     Disassemble                                1.467 secs
#     Disassemble Entry Points                   5.193 secs
#     Embedded Media                             0.042 secs
#     External Entry References                  0.009 secs
#     Function Start Pre Search                  0.032 secs
#     Function Start Search                      0.534 secs
#     GCC Exception Handlers                     0.078 secs
#     Non-Returning Functions - Discovered       0.387 secs
#     Non-Returning Functions - Known            0.008 secs
#     Shared Return Calls                        0.148 secs
#     Subroutine References                      0.321 secs
# -----------------------------------------------------
#      Total Time   37 secs
# -----------------------------------------------------
#  (AutoAnalysisManager)
# ERROR REPORT: Analysis timed out at 30 seconds. Processing not completed for file: file:///local/AC15/AC15_httpd?MD5=35a3115eb9749638fd5e19c26c7fa752 (HeadlessAnalyzer)
# INFO  SCRIPT: /local/gheadless.py (HeadlessAnalyzer)
# INFO  ANALYZING changes made by post scripts: file:///local/AC15/AC15_httpd?MD5=35a3115eb9749638fd5e19c26c7fa752 (HeadlessAnalyzer)
# INFO  REPORT: Post-analysis succeeded for file: file:///local/AC15/AC15_httpd?MD5=35a3115eb9749638fd5e19c26c7fa752 (HeadlessAnalyzer)
# INFO  REPORT: Save succeeded for: /AC15/AC15_httpd (TeamProject:/AC15/AC15_httpd) (HeadlessAnalyzer)
# INFO  REPORT: Import succeeded (HeadlessAnalyzer)
# INFO  IMPORTING: file:///local/AC15/TRI227WF_webs?MD5=8c149607136281c97339f27d0280d1b9 (HeadlessAnalyzer)
# INFO  Using Loader: Executable and Linking Format (ELF) (AutoImporter)
# INFO  Using Language/Compiler: ARM:LE:32:v8:default (AutoImporter)
# INFO  Additional info:
# Loading file:///local/AC15/TRI227WF_webs?MD5=8c149607136281c97339f27d0280d1b9...
# ELF Relocation Failure: R_ARM_COPY (20, 0x14) at 0006476c (Symbol = __ctype_b) - Runtime copy not supported (4-bytes)
# ELF Relocation Failure: R_ARM_COPY (20, 0x14) at 00064770 (Symbol = __ctype_toupper) - Runtime copy not supported (4-bytes)
# ELF Relocation Failure: R_ARM_COPY (20, 0x14) at 00064774 (Symbol = __ctype_tolower) - Runtime copy not supported (4-bytes)
# Setting block .init_array to read-only
# Setting block .fini_array to read-only
# Setting block .jcr to read-only
# Setting block .dynamic to read-only
# ------------------------------------------------
#
# Linking the External Programs of 'TRI227WF_webs' to imported libraries...
#   [libgcc_s.so.1] -> not found in project
#   [libc.so.0] -> not found in project
# ------------------------------------------------
#
# Resolving External Symbols of [/AC15/TRI227WF_webs] - 94 unresolved symbols, no external libraries configured - skipping
#  (AutoImporter)
# INFO  IMPORTING: Loaded 0 additional files (HeadlessAnalyzer)
# INFO  ANALYZING all memory and code: file:///local/AC15/TRI227WF_webs?MD5=8c149607136281c97339f27d0280d1b9 (HeadlessAnalyzer)
# INFO  hit non-returning function, restarting decompiler switch analyzer later (DecompilerSwitchAnalyzer)
# INFO  Packed database cache: /var/tmp/root-ghidra/packed-db-cache (PackedDatabaseCache)
# INFO  Applied data type archive: generic_clib (ApplyDataArchiveAnalyzer)
# INFO  -----------------------------------------------------
#     ARM Constant Reference Analyzer            6.009 secs
#     ARM Symbol                                 0.001 secs
#     ASCII Strings                              0.668 secs
#     Apply Data Archives                        0.771 secs
#     Call Convention ID                         0.533 secs
#     Call-Fixup Installer                       0.008 secs
#     Create Address Tables                      0.093 secs
#     Create Address Tables - One Time           0.176 secs
#     Create Function                            0.288 secs
#     Data Reference                             0.367 secs
#     Decompiler Switch Analysis                 2.841 secs
#     Decompiler Switch Analysis - One Time      0.000 secs
#     Demangler GNU                              0.027 secs
#     Disassemble                                1.384 secs
#     Disassemble Entry Points                   0.085 secs
#     Embedded Media                             0.009 secs
#     External Entry References                  0.001 secs
#     Function Start Pre Search                  0.007 secs
#     Function Start Search                      0.166 secs
#     Function Start Search After Code           0.478 secs
#     Function Start Search After Data           0.336 secs
#     Function Start Search delayed - One Time   0.010 secs
#     GCC Exception Handlers                     0.001 secs
#     Non-Returning Functions - Discovered       0.199 secs
#     Non-Returning Functions - Known            0.002 secs
#     Reference                                  0.689 secs
#     Shared Return Calls                        0.054 secs
#     Stack                                      5.019 secs
#     Subroutine References                      0.990 secs
#     Subroutine References - One Time           0.000 secs
# -----------------------------------------------------
#      Total Time   21 secs
# -----------------------------------------------------
#  (AutoAnalysisManager)
# INFO  REPORT: Analysis succeeded for file: file:///local/AC15/TRI227WF_webs?MD5=8c149607136281c97339f27d0280d1b9 (HeadlessAnalyzer)
# INFO  SCRIPT: /local/gheadless.py (HeadlessAnalyzer)
# INFO  ANALYZING changes made by post scripts: file:///local/AC15/TRI227WF_webs?MD5=8c149607136281c97339f27d0280d1b9 (HeadlessAnalyzer)
# INFO  REPORT: Post-analysis succeeded for file: file:///local/AC15/TRI227WF_webs?MD5=8c149607136281c97339f27d0280d1b9 (HeadlessAnalyzer)
# INFO  REPORT: Save succeeded for: /AC15/TRI227WF_webs (TeamProject:/AC15/TRI227WF_webs) (HeadlessAnalyzer)
# INFO  REPORT: Import succeeded (HeadlessAnalyzer)
# CPU times: user 1.42 s, sys: 521 ms, total: 1.94 s
# Wall time: 1min 19s

# %% [markdown]
# <h2>Creating a Pandas Dataframe from a CSV</h2>

# %%
# %%time
df = pd.read_csv("./ghidratest.csv", header=None)
# Out:
# CPU times: user 7.14 ms, sys: 7.48 ms, total: 14.6 ms
# Wall time: 15.1 ms

# %% [markdown]
# <h2>Naming Pandas Columns</h2>

# %%
# %%time
df.columns = [
    "File",
    "Architecture",
    "SHA256",
    "Strings",
    "Functions",
    "System_Xrefs",
    "Total_System_Xrefs",
    "Average_Cyclomatic_Complexity",
]
# Out:
# CPU times: user 666 μs, sys: 0 ns, total: 666 μs
# Wall time: 672 μs

# %%
df.fillna("None", inplace=True)

# %% [markdown]
# <h2>Verify the Pandas Output</h2>

# %%
# %%time
df
# Out:
# CPU times: user 2 μs, sys: 1 μs, total: 3 μs
# Wall time: 5.72 μs
#             File      Architecture  \
# 0     AC15_httpd  ARM/little/32/v8
# 1  TRI227WF_webs  ARM/little/32/v8
#
#                                               SHA256  \
# 0  e2880dc6a19a9ac5122d8686047db12a223d062324de7c...
# 1  800b296c5baa8d5d2dc5fba26ac2fc6c0e2f92b13e9f4b...
#
#                                              Strings  \
# 0  ds "ELF", ds "/lib/ld-uClibc.so.0", utf8 u8"li...
# 1  ds "ELF", ds "/lib/ld-linux.so.3", utf8 u8"lib...
#
#                                            Functions  \
# 0  _init, <EXTERNAL>::tpi_wan_get_extra_ip_info, ...
# 1  _DT_INIT, <EXTERNAL>::clock_gettime, <EXTERNAL...
#
#                                         System_Xrefs  Total_System_Xrefs  \
# 0  0003db54 (FUN_0003da1c); 0004fc48 (TendaTelnet...                 162
# 1  00009934 (FUN_0000987c); 0003d8f0 (FUN_0003d87...                   4
#
#    Average_Cyclomatic_Complexity
# 0                            6.0
# 1                            5.0

# %% [markdown]
# <h2>Checking Pandas Datatypes</h2>

# %%
# %%time
df.dtypes
# Out:
# CPU times: user 989 μs, sys: 0 ns, total: 989 μs
# Wall time: 1 ms
# File                              object
# Architecture                      object
# SHA256                            object
# Strings                           object
# Functions                         object
# System_Xrefs                      object
# Total_System_Xrefs                 int64
# Average_Cyclomatic_Complexity    float64
# dtype: object

# %% [markdown]
# <h2>Changing Datatypes to String</h2>

# %%
# %%time
df["Strings"] = df["Strings"].astype(str)
df["Functions"] = df["Functions"].astype(str)
df["File"] = df["File"].astype(str)
df["Architecture"] = df["Architecture"].astype(str)
df["System_Xrefs"] = df["System_Xrefs"].astype(str)
# Out:
# CPU times: user 2.74 ms, sys: 0 ns, total: 2.74 ms
# Wall time: 2.59 ms

# %% [markdown]
# <h2>Searching for Features</h2>

# %%
df[df["Architecture"].str.contains("little", na=False)]
# Out:
#             File      Architecture  \
# 0     AC15_httpd  ARM/little/32/v8
# 1  TRI227WF_webs  ARM/little/32/v8
#
#                                               SHA256  \
# 0  e2880dc6a19a9ac5122d8686047db12a223d062324de7c...
# 1  800b296c5baa8d5d2dc5fba26ac2fc6c0e2f92b13e9f4b...
#
#                                              Strings  \
# 0  ds "ELF", ds "/lib/ld-uClibc.so.0", utf8 u8"li...
# 1  ds "ELF", ds "/lib/ld-linux.so.3", utf8 u8"lib...
#
#                                            Functions  \
# 0  _init, <EXTERNAL>::tpi_wan_get_extra_ip_info, ...
# 1  _DT_INIT, <EXTERNAL>::clock_gettime, <EXTERNAL...
#
#                                         System_Xrefs  Total_System_Xrefs  \
# 0  0003db54 (FUN_0003da1c); 0004fc48 (TendaTelnet...                 162
# 1  00009934 (FUN_0000987c); 0003d8f0 (FUN_0003d87...                   4
#
#    Average_Cyclomatic_Complexity
# 0                            6.0
# 1                            5.0

# %% [markdown]
# <h2>Using Query to Search for Features</h2>

# %%
df.query("Average_Cyclomatic_Complexity > 3")
# Out:
#             File      Architecture  \
# 0     AC15_httpd  ARM/little/32/v8
# 1  TRI227WF_webs  ARM/little/32/v8
#
#                                               SHA256  \
# 0  e2880dc6a19a9ac5122d8686047db12a223d062324de7c...
# 1  800b296c5baa8d5d2dc5fba26ac2fc6c0e2f92b13e9f4b...
#
#                                              Strings  \
# 0  ds "ELF", ds "/lib/ld-uClibc.so.0", utf8 u8"li...
# 1  ds "ELF", ds "/lib/ld-linux.so.3", utf8 u8"lib...
#
#                                            Functions  \
# 0  _init, <EXTERNAL>::tpi_wan_get_extra_ip_info, ...
# 1  _DT_INIT, <EXTERNAL>::clock_gettime, <EXTERNAL...
#
#                                         System_Xrefs  Total_System_Xrefs  \
# 0  0003db54 (FUN_0003da1c); 0004fc48 (TendaTelnet...                 162
# 1  00009934 (FUN_0000987c); 0003d8f0 (FUN_0003d87...                   4
#
#    Average_Cyclomatic_Complexity
# 0                            6.0
# 1                            5.0

# %%
df_sorted = df.sort_values(by="Total_System_Xrefs", ascending=False)

# %%
# %%time
df_sorted.plot_bokeh.bar(
    x="File",
    y="Total_System_Xrefs",
    figsize=(900, 700),
    title="Potentially Dangerous Calls To System",
    xlabel="Binary",
    ylabel="Total",
    vertical_xlabel=True,
)
# Out:
#   <div class="bk-root" id="0d313d83-383b-4988-9b92-cc7b57572d34" data-root-id="1039"></div>
# CPU times: user 104 ms, sys: 0 ns, total: 104 ms
# Wall time: 102 ms
# Figure(id='1039', ...)

# %% [markdown]
# <h2>Creating Charts Using Pandas Bokeh</h2>

# %%
df.plot_bokeh.bar(
    x="File",
    y=["Average_Cyclomatic_Complexity"],
    figsize=(900, 700),
    title="Average Cyclomatic Complexity",
    xlabel="File",
    ylabel="Average Cyclomatic Complexity",
    vertical_xlabel=True,
)
# Out:
#   <div class="bk-root" id="2d750f48-4684-478a-919a-8b6d69f0fd6f" data-root-id="1183"></div>
# Figure(id='1183', ...)

# %% [markdown]
# <h2>Reference Material</h2>

# %% [markdown]
# - 10 Minutes to Pandas: https://pandas.pydata.org/docs/user_guide/10min.html
# - Pandas Cookbook: https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook
# - Ghidra API: https://ghidra.re/ghidra_docs/api/index.html
# - EMUX: https://github.com/therealsaumil/emux
# - Ghidra Snippets: https://github.com/HackOvert/GhidraSnippets
# - Auditing system calls for command injection vulnerabilities using Ghidra's PCode: https://youtu.be/UVNeg7Vqytc
# - cetfor/SystemCallAuditorGhidra.py: https://github.com/HackOvert/PotentiallyVulnerable/blob/main/CWE-78/SystemCallAuditorGhidra.py
